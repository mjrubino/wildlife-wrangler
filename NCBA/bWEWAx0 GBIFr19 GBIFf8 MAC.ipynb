# %% [markdown]
# # Worm-eating Warbler Occurrence Records Summary
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### General Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
#import geopandas as gpd
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
# %cd ..
import repo_functions as functions
# Out:
# /Users/nmtarr/Code/occurrence-records-wrangler

# %% [markdown]
# ### Set Variables
# Fill out stuff in this cell.

# %%
species_id = 'bwewax0'
summary_name = 'NCWormie'
gbif_req_id = 'GBIFr19'
gbif_filter_id = 'GBIFf8'
workDir = '/Users/nmtarr/Documents/NCBA/Data/'
codeDir = '/Users/nmtarr/Code/occurrence-records-wrangler/'
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
default_coordUncertainty = 8046
SRID_dict = {'WGS84': 4326, 'AlbersNAD83': 102008} # Used in file names for output.
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'

print("Notebook run " + str(t1))
# Out:
# Notebook run 2019-10-16 16:13:52.414596

# %%
connjup = sqlite3.connect(codeDir + 'parameters.sqlite')
cursorjup = connjup.cursor()

# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'breeding_months': '5,6,7',
#  'common_name': 'worm-eating warbler',
#  'detection_distance_meters': 200,
#  'end_year': None,
#  'error_tolerance': 20,
#  'fws_id': '',
#  'gap_id': 'bwewax',
#  'gbif_id': '2489603',
#  'geometry': None,
#  'itis_tsn': '726195',
#  'migratory': '1',
#  'notes': 'Species name changed from vermivorus in 2003.  Breeding and '
#           'wintering months from Birds of North America Database (July 26, '
#           '2019).  Migration is possible in early May and late July. N. Tarr '
#           '26 July 2019.',
#  'pad': 1,
#  'scientific_name': 'Helmitheros vermivorum',
#  'species_id': 'bwewax0',
#  'start_year': 2003,
#  'wintering_months': '10,11,12,1,2'}

# %% [markdown]
# ## Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                                                          GBIFr19
# source                                                                 GBIF
# lat_range
# lon_range
# years_range                                                       2015,2020
# months_range                                                           1,12
# geoissue                                                              False
# coordinate                                                             True
# country
# geometry        POLYGON ((-84.48078517214034 34.91735591277285, -84.4181...
# continent                                                              None
# creator                                                             N. Tarr
# notes           Parameterized for NC Bird Atlas efforts.  Filterd on geo...
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                                                          GBIFf8
# dataset                                                                              GBIF
# collection_codes_omit                                                                None
# institutions_omit                                                                    None
# has_coordinate_uncertainty                                                              0
# max_coordinate_uncertainty                                                          10000
# bases_omit                                            PRESERVED_SPECIMEN, FOSSIL_SPECIMEN
# protocols_omit                                                                       None
# sampling_protocols_omit                                                              None
# issues_omit                   GEODETIC_DATUM_INVALID, INDIVIDUAL_COUNT_INVALID, MULTIM...
# creator                                                                           N. Tarr
# notes                                                                      Built for NCBA
# Name: 0, dtype: object

# %% [markdown]
# ### Filter set justification
# **default_coord_uncertainty**: Many eBird records should be returned and the locational uncertainty could be near 5 miles (8046 m) due to the inclusion of traveling counts.
#
# **years_range**: I included the last 5 years since bird atlases run 3 to 5 years.
#
# **months_range**: Included all months for now in order to see what is returned.  It may be best to limit to certain months eventually.
#
# **geoissue**: Errors in location are too problematic to include.
#
# **coordinate**: Use of records in maps and spatial queries requires that records have x,y coordinates.
#
# **continent**: This parameter is not useful and thus left blank.
#
# **collection_codes_omit**: For now, interested in what comes back.
#
# **institutions_omit**: For now, interested in what comes back.
#
# **has_coordinate_uncertainty**: This parameter isn't useful because of vast majority not having a value.
#
# **max_coordinate_uncertainty**: Extremely high uncertainty isn't helpful, but moderately high uncertainty will be dealt with in the spatial comparison process.
#
# **bases_omit**: Fossils and preserved specimens wouldn't correspond to the questions a bird atlas seeks to answer.
#
# **protocols_omit**: For now, interested in what comes back.
#
# **sampling_protocols_omit**: For now, interested in what comes back.
#
# **issues_omit**: Omitting any issues that we have identified that are undesirable.

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, inDir, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, SRID_dict, outDir, summary_name)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.181104
# Downloaded records: 0:01:45.137932
# 	5229 records exist with the request parameters
# Created summary table of request results: 0:03:32.692765
# Performed post-request filtering: 0:00:00.204158
# Summarized results of filtering: 0:00:00.330932
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.331564, 'decimalLatitude': 35.128978, 'year': 2018, 'month': 5, 'day': 5, 'eventDate': '2018-05-05T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': '115 Moonshine Falls Trl, Landrum US-SC (35.1290,-82.3316)', 'gbifID': '2156477588', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS610977726', 'remarks': '; 115 Moonshine Falls Trl, Landrum US-SC (35.1290,-82.3316)', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 2, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -83.935354, 'decimalLatitude': 34.94096, 'year': 2016, 'month': 6, 'day': 4, 'eventDate': '2016-06-04T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Ravencliff FAA Rd.', 'gbifID': '1743453968', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS409648453', 'remarks': '; Ravencliff FAA Rd.', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.605214, 'decimalLatitude': 35.709601, 'year': 2015, 'month': 8, 'day': 13, 'eventDate': '2015-08-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': '40 Flack Valley Road', 'gbifID': '1382029568', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS336384542', 'remarks': '; 40 Flack Valley Road', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.605214, 'decimalLatitude': 35.709601, 'year': 2016, 'month': 8, 'day': 1, 'eventDate': '2016-08-01T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': '40 Flack Valley Road', 'gbifID': '1753454126', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS421183568', 'remarks': '; 40 Flack Valley Road', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 5, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.223375, 'decimalLatitude': 35.589062, 'year': 2015, 'month': 6, 'day': 5, 'eventDate': '2015-06-05T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Edmondson Mountain', 'gbifID': '1407493172', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS376767399', 'remarks': '; Edmondson Mountain', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 3, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -76.700771, 'decimalLatitude': 34.863609, 'year': 2017, 'month': 4, 'day': 30, 'eventDate': '2017-04-30T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Seagate Woods (Restricted Access)', 'gbifID': '2060496344', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS492839509', 'remarks': '; Seagate Woods (Restricted Access)', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 3, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.26393, 'decimalLatitude': 35.302514, 'year': 2015, 'month': 5, 'day': 3, 'eventDate': '2015-05-03T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Green River Game Land--Green River Cove Rd.', 'gbifID': '1369733249', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS321455786', 'remarks': '; Green River Game Land--Green River Cove Rd.', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 12, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -83.935354, 'decimalLatitude': 34.94096, 'year': 2016, 'month': 6, 'day': 11, 'eventDate': '2016-06-11T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Ravencliff FAA Rd.', 'gbifID': '1744736453', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS411224821', 'remarks': '; Ravencliff FAA Rd.', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 6, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -83.535924, 'decimalLatitude': 34.948931, 'year': 2016, 'month': 6, 'day': 25, 'eventDate': '2016-06-25T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Chestnut Mountain', 'gbifID': '1747083310', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS414080497', 'remarks': '; Chestnut Mountain', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -83.68075, 'decimalLatitude': 34.933508, 'year': 2016, 'month': 4, 'day': 19, 'eventDate': '2016-04-19T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Towns - 276 TV', 'gbifID': '1728905998', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS392906872', 'remarks': '; Towns - 276 TV', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.940276, 'decimalLatitude': 35.160604, 'year': 2017, 'month': 4, 'day': 29, 'eventDate': '2017-04-29T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Toxaway Trail', 'gbifID': '2059555068', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS491976339', 'remarks': '; Toxaway Trail', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -78.638634, 'decimalLatitude': 35.772049, 'year': 2016, 'month': 4, 'day': 24, 'eventDate': '2016-04-24T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Raleigh', 'gbifID': '1730579107', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS394743189', 'remarks': '; Raleigh', 'dataGeneralizations': ''}
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.306652, 'decimalLatitude': 36.133577, 'year': 2016, 'month': 6, 'day': 25, 'eventDate': '2016-06-25T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cherokee National Forest--Unaka Mountain', 'gbifID': '1747678403', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS414555752', 'remarks': '; Cherokee National Forest--Unaka Mountain', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -81.829219, 'decimalLatitude': 36.082436, 'year': 2016, 'month': 5, 'day': 30, 'eventDate': '2016-05-30T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Blue Ridge Pkwy--Beacon Heights', 'gbifID': '1742854659', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS408963215', 'remarks': '; Blue Ridge Pkwy--Beacon Heights', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.737667, 'decimalLatitude': 35.152675, 'year': 2018, 'month': 4, 'day': 19, 'eventDate': '2018-04-19T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'NC Backyard', 'gbifID': '2148884678', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS602163642', 'remarks': '; NC Backyard', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 17, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.12402, 'decimalLatitude': 35.739441, 'year': 2016, 'month': 6, 'day': 6, 'eventDate': '2016-06-06T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Hwy 80 - Sunnyvale', 'gbifID': '1750483589', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS417913847', 'remarks': '; Hwy 80 - Sunnyvale', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 4, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.803869, 'decimalLatitude': 35.309394, 'year': 2017, 'month': 4, 'day': 25, 'eventDate': '2017-04-25T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'FR 225', 'gbifID': '2047326506', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS490621749', 'remarks': '; FR 225', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -83.432751, 'decimalLatitude': 35.464865, 'year': 2016, 'month': 6, 'day': 12, 'eventDate': '2016-06-12T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Great Smoky Mountains NP--Deep Creek Campground', 'gbifID': '1745031112', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS411573176', 'remarks': '; Great Smoky Mountains NP--Deep Creek Campground', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -76.488018, 'decimalLatitude': 36.625321, 'year': 2016, 'month': 4, 'day': 16, 'eventDate': '2016-04-16T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Great Dismal Swamp NWR', 'gbifID': '1728150084', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS391826663', 'remarks': '; Great Dismal Swamp NWR', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.791994, 'decimalLatitude': 35.099036, 'year': 2017, 'month': 8, 'day': 30, 'eventDate': '2017-08-30T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'US-NC-Rosman-253 Turkey Track Rd', 'gbifID': '2089242656', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS528924077', 'remarks': '; US-NC-Rosman-253 Turkey Track Rd', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 4, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -83.957004, 'decimalLatitude': 34.923871, 'year': 2015, 'month': 6, 'day': 7, 'eventDate': '2015-06-07T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Ivy Log Gap Road (Union Co.)', 'gbifID': '1373703217', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS326233351', 'remarks': '; Ivy Log Gap Road (Union Co.)', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -83.896666, 'decimalLatitude': 34.932984, 'year': 2017, 'month': 4, 'day': 29, 'eventDate': '2017-04-29T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Ivy Log Gap Road--Towns Co. end', 'gbifID': '2048144428', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS492174303', 'remarks': '; Ivy Log Gap Road--Towns Co. end', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 2, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -81.440484, 'decimalLatitude': 36.261924, 'year': 2016, 'month': 5, 'day': 2, 'eventDate': '2016-05-02T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Blue Ridge Pkwy--Lewis Fork Overlook', 'gbifID': '1733349506', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS397854823', 'remarks': '; Blue Ridge Pkwy--Lewis Fork Overlook', 'dataGeneralizations': ''}
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 4, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.249575, 'decimalLatitude': 35.432177, 'year': 2018, 'month': 4, 'day': 28, 'eventDate': '2018-04-28T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Chimney Rock SP', 'gbifID': '2168488256', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS623865412', 'remarks': '; Chimney Rock SP', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -80.909328, 'decimalLatitude': 35.355736, 'year': 2015, 'month': 4, 'day': 30, 'eventDate': '2015-04-30T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Latta Plantation Nature Preserve', 'gbifID': '1363493758', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS314296482', 'remarks': '; Latta Plantation Nature Preserve', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -75.86201, 'decimalLatitude': 35.864075, 'year': 2016, 'month': 5, 'day': 5, 'eventDate': '2016-05-05T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Alligator River NWR', 'gbifID': '1734061950', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS398698079', 'remarks': '; Alligator River NWR', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -81.440484, 'decimalLatitude': 36.261924, 'year': 2015, 'month': 5, 'day': 9, 'eventDate': '2015-05-09T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Blue Ridge Pkwy--Lewis Fork Overlook', 'gbifID': '1366516902', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS317856139', 'remarks': '; Blue Ridge Pkwy--Lewis Fork Overlook', 'dataGeneralizations': ''}
#
# There was a problem with the following record:
# UNIQUE constraint failed: occurrences.occ_id
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 3, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -82.080478, 'decimalLatitude': 36.266527, 'year': 2015, 'month': 6, 'day': 13, 'eventDate': '2015-06-13T00:00:00', 'issues': ['COORDINATE_ROUNDED'], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cherokee NF--Pond Mountain (Laurel Fork Road)', 'gbifID': '1374061711', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS326809970', 'remarks': '; Cherokee NF--Pond Mountain (Laurel Fork Road)', 'dataGeneralizations': ''}
# Performed post-request filtering: 0:00:18.089910
# Removed duplicates: 0:00:00.053340
# 	1449 duplicates were deleted
# Buffered points: 0:00:02.722104
# Exported maps: 0:00:01.051085
#
# Records saved in /Users/nmtarr/Documents/NCBA/Data/Outputs/bwewax0GBIFr19GBIFf8.sqlite

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 3752 records

# %% [markdown]
# ### Were there duplicate records?
# needs to be addressed

# %%
dups0 = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences GROUP BY geom_xy4326, occurrenceDate;").fetchall()
dups1 = [x[0] for x in dups0]
dups2 = [x for x in dups1 if x > 1]
print(str(len(dups2)) + ' records were duplicates based on xy coordinate and date-time')
# Out:
# 0 records were duplicates based on xy coordinate and date-time

# %% [markdown]
# # Institutions
# #### Pre-filters

# %%
institutions = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'institutions';").fetchall()
for x in institutions:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# CLO (5209)
# iNaturalist (18)
# unknown (2)

# %% [markdown]
# #### Post-filter

# %%
institutions = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'institutions' AND step = 'filter';").fetchone()[0]
institutions = institutions.replace('[', '').strip().replace(']', '').replace("'", "")
institutions = institutions.split(',')
for ins in institutions:
    print(ins.strip())
# Out:
# CLO
# iNaturalist
# UNKNOWN

# %% [markdown]
# # Collections
# #### Pre-filters

# %%
collections = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'collections';").fetchall()
for x in collections:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# EBIRD (5199)
# Observations (18)
# Bird sounds (2)
# EBIRD_CAMERICA (5)
# EBIRD_PNW (3)
# EBIRD_VINS (1)
# EBIRD_VA (1)

# %% [markdown]
# #### Post-filters

# %%
collections = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'collections' AND step = 'filter';").fetchone()[0]
collections = collections.replace('[', '').strip().replace(']', '').replace("'", "")
collections = collections.split(',')
for colls in collections:
    print(colls.strip())
# Out:
# Observations
# EBIRD_VINS
# EBIRD
# EBIRD_VA
# Bird sounds
# EBIRD_PNW
# EBIRD_CAMERICA

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'bases';").fetchall()
for x in bases:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# HUMAN_OBSERVATION (5229)

# %% [markdown]
# #### Post-filters

# %%
bases = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'bases' AND step = 'filter';").fetchone()[0]
bases = bases.replace('[', '').strip().replace(']', '').replace("'", "")
bases = bases.split(",")
for bas in bases:
    print(bas.strip())
# Out:
# HUMAN_OBSERVATION

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocols = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'protocols';").fetchall()
for x in protocols:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# DWC_ARCHIVE (5229)

# %% [markdown]
# #### Post-filters

# %%
protos = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'protocols' AND step = 'filter';").fetchall()[0]
for pro in protos:
    pro = pro.replace('[', '').strip().replace(']', '').replace("'", "")
    print(pro)
# Out:
# DWC_ARCHIVE

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
issues = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'issues';").fetchall()
for x in issues:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# COORDINATE_ROUNDED (4158)
# GEODETIC_DATUM_ASSUMED_WGS84 (19)

# %% [markdown]
# #### Post-filters

# %%
issues = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'issues' AND step = 'filter';").fetchone()[0]
issues = issues.replace('[', '').strip().replace(']', '').replace("'", "")
issues = issues.split(',')
for iss in issues:
    print(iss.strip())
# Out:
# COORDINATE_ROUNDED
# GEODETIC_DATUM_ASSUMED_WGS84

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_circles'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of occurrences")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of occurrences")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %% [markdown]
# ### Geodetic datums present

# %%
datums = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'datums' AND step = 'filter';").fetchone()[0]
datums = datums.replace('[', '').strip().replace(']', '').replace("'", "")
datums = datums.split()
for datum in datums:
    print(datum)
# Out:
# WGS84

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM record_attributes WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
#remarks = remarks.replace('[', '').strip().replace(']', '').replace("'", "")
#remarks = remarks.split(',')
if len(remarks) <= 20:
    for rem in remarks:
        if rem[0][0:1] == ';':
            print(rem[0][2:])
        else:
            print(rem[0])
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Sources

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])
# Out:
# GBIF

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ, index_col='index')
fields_summary.index.name = 'field'
print(fields_summary)
# Out:
#                                       included(n)  populated(n)
# field
# acceptedScientificName                       5229          5229
# acceptedTaxonKey                             5229          5229
# associatedTaxa                                  1             1
# basisOfRecord                                5229          5229
# behavior                                        2             2
# catalogNumber                                5229          5229
# class                                        5229          5229
# classKey                                     5229          5229
# collectionCode                               5229          5229
# coordinateUncertaintyInMeters                  15            15
# country                                      5229          5229
# countryCode                                  5229          5229
# county                                       5209          5209
# crawlId                                      5229          5229
# datasetKey                                   5229          5229
# datasetName                                    18            18
# dateIdentified                                 17            17
# day                                          5229          5229
# decimalLatitude                              5229          5229
# decimalLongitude                             5229          5229
# eventDate                                    5229          5229
# eventTime                                      19            19
# extensions                                   5229             0
# facts                                        5229             0
# family                                       5229          5229
# familyKey                                    5229          5229
# fieldNotes                                      2             2
# gbifID                                       5229          5229
# genericName                                  5229          5229
# genus                                        5229          5229
# genusKey                                     5229          5229
# geodeticDatum                                5229          5229
# higherClassification                            2             2
# http://unknown.org/nick                        18            18
# http://unknown.org/occurrenceDetails           18            18
# identificationID                               17            17
# identificationRemarks                           1             1
# identifier                                   5211          5211
# identifiers                                  5229             0
# individualCount                              5134          5134
# installationKey                              5229          5229
# institutionCode                              5227          5227
# issues                                       5229          4159
# key                                          5229          5229
# kingdom                                      5229          5229
# kingdomKey                                   5229          5229
# lastCrawled                                  5229          5229
# lastInterpreted                              5229          5229
# lastParsed                                   5229          5229
# license                                      5229          5229
# locality                                     5211          5211
# media                                        5229            18
# modified                                       18            18
# month                                        5229          5229
# nomenclaturalCode                               2             2
# occurrenceID                                 5229          5229
# occurrenceRemarks                               2             2
# order                                        5229          5229
# orderKey                                     5229          5229
# phylum                                       5229          5229
# phylumKey                                    5229          5229
# protocol                                     5229          5229
# publishingCountry                            5229          5229
# publishingOrgKey                             5229          5229
# recordedBy                                   5229          5229
# references                                     20            20
# relations                                    5229             0
# rights                                         18            18
# rightsHolder                                   20            20
# scientificName                               5229          5229
# species                                      5229          5229
# speciesKey                                   5229          5229
# specificEpithet                              5229          5229
# stateProvince                                5227          5227
# taxonID                                        18            18
# taxonKey                                     5229          5229
# taxonRank                                    5229          5229
# taxonomicStatus                              5229          5229
# verbatimElevation                               2             2
# verbatimEventDate                              20            20
# verbatimLocality                               18            18
# vernacularName                                  2             2
# year                                         5229          5229

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:05:51.172026
