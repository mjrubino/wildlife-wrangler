# %% [markdown]
# # Example sp.
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### Set Variables - fill out stuff in this cell.
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
species_id = 'bybcux0'
summary_name = 'cuckoo23-9'
gbif_req_id = 'GBIFr23'
gbif_filter_id = 'GBIFf9'
default_coordUncertainty = 1000       # Note above.
workDir = 'T:/Occurrence_Records/'  # Be sure to create folders named "Inputs" and "Outputs" here.
codeDir = 'T:/Code/Wildlife-Wrangler/'
paramdb = 'P:/Proj3/USGap/Vert/DBase/wildlife-wrangler.sqlite'
configDir = 'T:/GAP/Data/'  # Path to folder where saved your wildlifeconfig file.

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temp fix, hopefully.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410

# %%
import os
os.environ['PROJ_LIB'] = r'c:\Users\nmtarr\AppData\Local\Continuum\miniconda3\envs\wrangler\Library\share'

# %% [markdown]
# ### Setup - nothing to fill out in this cell

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
sys.path.append(codeDir)
import repo_functions as functions
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
# Out:
# Notebook run 2020-03-25 12:55:26.671431
# T:/Occurrence_Records/Outputs/bybcux0GBIFr23GBIFf9.sqlite

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
sp_dict = dict(zip(cols, vals))
sp_df = pd.DataFrame.from_dict(sp_dict, orient='index', columns=['VALUE'])
sp_df.index.name = 'ATTRIBUTE'
print("SPECIES CONCEPT RECORD")
print(sp_df)
# Out:
# SPECIES CONCEPT RECORD
#                                                    VALUE
# ATTRIBUTE
# species_id                                       bybcux0
# fws_id                                              None
# gap_id                                            bybcux
# itis_tsn                                          177831
# gbif_id                                          2496287
# bcb_id                                              None
# ebird_id                                            None
# common_name                         yellow-billed cuckoo
# scientific_name                      Coccyzus americanus
# start_year                                          None
# split_from                                          None
# end_year                                            None
# lumped_into                                         None
# geometry                                            None
# detection_distance_meters                            100
# vetted_how                                          None
# vetted_who                                          None
# vetted_date                                         None
# notes                      Manually entered for use i...

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
request_df = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(request_df.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                    GBIFr23
# source                           GBIF
# lat_range                        None
# lon_range                        None
# years_range                 2000,2020
# months_range                     1,12
# geoissue                         None
# coordinate                       True
# country                            US
# geometry                         None
# creator                       N. Tarr
# notes           Used for speed tests.
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
filter_df = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(filter_df.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                            GBIFf9
# dataset                                                GBIF
# institutions_omit                                      None
# collection_codes_omit                                  None
# datasets_omit                                          None
# has_coordinate_uncertainty                                0
# max_coordinate_uncertainty                            10000
# bases_omit                                             None
# sampling_protocols_omit                                None
# issues_omit                                            None
# duplicates_OK                                          True
# creator                                             N. Tarr
# notes                         Used for speed tests.  Let...
# Name: 0, dtype: object

# %% [markdown]
# ## Filter set justification - ENTER your justification for the following settings.
#
# **default_coord_uncertainty:**
#
# **years_range:**
#
# **months_range:**
#
# **geoissue:**
#
# **coordinate:**
#
# **country:**
#
# **geometry:**
#
# **collection_codes_omit:**
#
# **institutions_omit:**
#
# **datasets_omit:**
#
# **has_coordinate_uncertainty:**
#
# **max_coordinate_uncertainty:**
#
# **bases_omit:**
#
# **sampling_protocols_omit:**
#
# **issues_omit:**
#
# **duplicates:**

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, inDir, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                   password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.317651
# Got request params and sorted out geometry constraints: 0:00:00.023899
# 457482 records available
# Your download key is  0029769-200221144449610
# Downloading Darwin Core Archive zip file for this species .....
# Download file size: 102400483 bytes
# On disk at T:/Occurrence_Records/Inputs//0029769-200221144449610.zip
# Download complete: 0:08:40.481184
# basisOfRecord                     object
# collectionCode                    object
# coordinateUncertaintyInMeters    float64
# dataGeneralizations               object
# datasetName                       object
# latitude                         float64
# longitude                        float64
# establishmentMeans                object
# occurrenceDate                    object
# eventRemarks                      object
# footprintWKT                      object
# occ_id                             int64
# identificationQualifier           object
# individualCount                  float64
# institutionCode                   object
# institutionID                     object
# issues                            object
# locality                          object
# locationRemarks                   object
# occurrenceRemarks                 object
# samplingProtocol                  object
# scientificName                    object
# dtype: object
# basisOfRecord                     object
# collectionCode                    object
# coordinateUncertaintyInMeters    float64
# dataGeneralizations               object
# datasetName                       object
# latitude                          object
# longitude                         object
# establishmentMeans                object
# occurrenceDate                    object
# eventRemarks                      object
# footprintWKT                      object
# occ_id                             int64
# identificationQualifier           object
# individualCount                  float64
# institutionCode                   object
# institutionID                     object
# issues                            object
# locality                          object
# locationRemarks                   object
# occurrenceRemarks                 object
# samplingProtocol                  object
# scientificName                    object
# dtype: object
# Downloaded and loaded records: 0:00:25.760879
# Summarized fields returned: 0:00:02.049593
# Created summary table of request results: 0:00:00.476003
# Performed post-request filtering: 0:00:00.957941
# Calculated new columns, deleted some too: 0:00:00.842808
# DUPLICATES ON LATITUDE, LONGITUDE, DATE-TIME INCLUDED
# Inserted records into table: 0:00:10.470745
# Summarized unique values retained: 0:00:00.162717
# Updated occurrences table geometry column: 0:02:10.459817
# Buffered points: 0:05:12.813096
# Exported maps: 0:02:04.681684
#
# Records saved in T:/Occurrence_Records/Outputs/bybcux0GBIFr23GBIFf9.sqlite

# %% [markdown]
# ### Connect to output database, record species and filter info.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
sp_df.to_sql(name='species_concept', con=conn_occ, if_exists='replace')
request_df.to_sql(name=gbif_req_id, con=conn_occ, if_exists='replace')
filter_df.to_sql(name=gbif_filter_id, con=conn_occ, if_exists='replace')

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 457417 records

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#                   institutionCode                 collectionCode                    datasetName       0
# 0                            AMNH                          Birds           AMNH Bird Collection      14
# 1   BSC; Bird Studies Canada -...  MMP; Marsh Monitoring Prog...  Marsh Monitoring Program -...       6
# 2   Borror Laboratory of Bioac...                     Recordings  Borror Lab of Bioacoustics...       2
# 3                             CAS                            ORN          CAS Ornithology (ORN)       4
# 4                            CHAS                 Bird specimens      CHAS Ornithology (Arctos)       2
# 5                             CLO                          EBIRD  EOD - eBird Observation Da...  434437
# 6                             CLO                       EBIRD_AK  EOD - eBird Observation Da...      46
# 7                             CLO                      EBIRD_ARG  EOD - eBird Observation Da...       3
# 8                             CLO                       EBIRD_AU  EOD - eBird Observation Da...      18
# 9                             CLO                      EBIRD_BCN  EOD - eBird Observation Da...    1099
# 10                            CLO                      EBIRD_BRA  EOD - eBird Observation Da...       2
# 11                            CLO                 EBIRD_CAMERICA  EOD - eBird Observation Da...      65
# 12                            CLO                      EBIRD_CAN  EOD - eBird Observation Da...     298
# 13                            CLO                       EBIRD_CB  EOD - eBird Observation Da...      14
# 14                            CLO                       EBIRD_CL  EOD - eBird Observation Da...      13
# 15                            CLO                      EBIRD_ESP  EOD - eBird Observation Da...       5
# 16                            CLO                      EBIRD_IND  EOD - eBird Observation Da...      10
# 17                            CLO                    EBIRD_KIOSK  EOD - eBird Observation Da...      60
# 18                            CLO                     EBIRD_LWBA  EOD - eBird Observation Da...    2468
# 19                            CLO                       EBIRD_MA  EOD - eBird Observation Da...     270
# 20                            CLO                       EBIRD_ME  EOD - eBird Observation Da...      99
# 21                            CLO                      EBIRD_MEX  EOD - eBird Observation Da...      53
# 22                            CLO                       EBIRD_MO  EOD - eBird Observation Da...     383
# 23                            CLO                      EBIRD_MYS  EOD - eBird Observation Da...       3
# 24                            CLO                       EBIRD_NH  EOD - eBird Observation Da...     283
# 25                            CLO                       EBIRD_NJ  EOD - eBird Observation Da...    1176
# 26                            CLO                       EBIRD_NZ  EOD - eBird Observation Da...       1
# 27                            CLO                       EBIRD_PA  EOD - eBird Observation Da...    2242
# 28                            CLO                       EBIRD_PE  EOD - eBird Observation Da...       2
# 29                            CLO                      EBIRD_PNW  EOD - eBird Observation Da...     147
# 30                            CLO                       EBIRD_PR  EOD - eBird Observation Da...       6
# 31                            CLO                      EBIRD_PRY  EOD - eBird Observation Da...       1
# 32                            CLO                       EBIRD_QC  EOD - eBird Observation Da...     153
# 33                            CLO                      EBIRD_TWN  EOD - eBird Observation Da...       3
# 34                            CLO                       EBIRD_TX  EOD - eBird Observation Da...    8893
# 35                            CLO                       EBIRD_VA  EOD - eBird Observation Da...    1667
# 36                            CLO                     EBIRD_VINS  EOD - eBird Observation Da...     453
# 37                            CLO                       EBIRD_WI  EOD - eBird Observation Da...    1336
# 38                            CLO                           GBBC      Great Backyard Bird Count       1
# 39                            CLO                             ML  Macaulay Library Audio and...      47
# 40                           CUMV                           Bird           CUMV Bird Collection       8
# 41                           DMNH                           Bird                     DMNH Birds       2
# 42                           DMNS                 Bird specimens  DMNS Bird Collection (Arctos)       7
# 43                           FMNH                          Birds  Field Museum of Natural Hi...      43
# 44                             KU                          Birds    KUBI Ornithology Collection      16
# 45                           LACM                          Birds     LACM Vertebrate Collection       3
# 46                            MCZ                            Orn  Museum of Comparative Zool...       6
# 47                            MLZ                 Bird specimens   MLZ Bird Collection (Arctos)       1
# 48                           MMNH                           Bird              Bell Museum birds       1
# 49                            MSB                 Bird specimens   MSB Bird Collection (Arctos)       7
# 50                            MVZ                Bird eggs/nests  MVZ Egg and Nest Collectio...       1
# 51                            MVZ                 Bird specimens   MVZ Bird Collection (Arctos)       2
# 52                           OMNH                          Birds                Birds Specimens       4
# 53                           OMNH                           OCGR              Tissues Specimens      14
# 54  Ohio State University - Bi...                          Birds  Ohio State University Tetr...       4
# 55                           PRBO                        PRBO-PC  Point Reyes Bird Observato...       7
# 56                          SBMNH                             AV       SBMNH Vertebrate Zoology       2
# 57                          SDNHM                          Birds         SDNHM Birds Collection       2
# 58                           TCWC                          Birds  Biodiversity Research and ...      19
# 59                           UMMZ                          birds  University of Michigan Mus...      50
# 60                           UWBM                           Bird    UWBM Ornithology Collection       7
# 61                          UWYMV                 Bird specimens  UWYMV Bird Collection (Arc...       1
# 62                            VCE                          VBBA2  The Second Breeding Bird A...      95
# 63                            YPM                             VZ  Vertebrate Zoology Divisio...       3
# 64                    iNaturalist                   Observations  iNaturalist Research-grade...    1242
# 65                    naturgucker                    naturgucker                    naturgucker      31

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#                   institutionCode                 collectionCode                    datasetName  COUNT(occ_id)
# 0                            None                           None         Questagame weekly feed              1
# 1                            None                    Bird sounds  Xeno-canto - Bird sounds f...            118
# 2                            AMNH                          Birds           AMNH Bird Collection             14
# 3   BSC; Bird Studies Canada -...  MMP; Marsh Monitoring Prog...  Marsh Monitoring Program -...              6
# 4   Borror Laboratory of Bioac...                     Recordings  Borror Lab of Bioacoustics...              2
# 5                             CAS                            ORN          CAS Ornithology (ORN)              4
# 6                            CHAS                 Bird specimens      CHAS Ornithology (Arctos)              2
# 7                             CLO                          EBIRD  EOD - eBird Observation Da...         434437
# 8                             CLO                       EBIRD_AK  EOD - eBird Observation Da...             46
# 9                             CLO                      EBIRD_ARG  EOD - eBird Observation Da...              3
# 10                            CLO                       EBIRD_AU  EOD - eBird Observation Da...             18
# 11                            CLO                      EBIRD_BCN  EOD - eBird Observation Da...           1099
# 12                            CLO                      EBIRD_BRA  EOD - eBird Observation Da...              2
# 13                            CLO                 EBIRD_CAMERICA  EOD - eBird Observation Da...             65
# 14                            CLO                      EBIRD_CAN  EOD - eBird Observation Da...            298
# 15                            CLO                       EBIRD_CB  EOD - eBird Observation Da...             14
# 16                            CLO                       EBIRD_CL  EOD - eBird Observation Da...             13
# 17                            CLO                      EBIRD_ESP  EOD - eBird Observation Da...              5
# 18                            CLO                      EBIRD_IND  EOD - eBird Observation Da...             10
# 19                            CLO                    EBIRD_KIOSK  EOD - eBird Observation Da...             60
# 20                            CLO                     EBIRD_LWBA  EOD - eBird Observation Da...           2468
# 21                            CLO                       EBIRD_MA  EOD - eBird Observation Da...            270
# 22                            CLO                       EBIRD_ME  EOD - eBird Observation Da...             99
# 23                            CLO                      EBIRD_MEX  EOD - eBird Observation Da...             53
# 24                            CLO                       EBIRD_MO  EOD - eBird Observation Da...            383
# 25                            CLO                      EBIRD_MYS  EOD - eBird Observation Da...              3
# 26                            CLO                       EBIRD_NH  EOD - eBird Observation Da...            283
# 27                            CLO                       EBIRD_NJ  EOD - eBird Observation Da...           1176
# 28                            CLO                       EBIRD_NZ  EOD - eBird Observation Da...              1
# 29                            CLO                       EBIRD_PA  EOD - eBird Observation Da...           2242
# 30                            CLO                       EBIRD_PE  EOD - eBird Observation Da...              2
# 31                            CLO                      EBIRD_PNW  EOD - eBird Observation Da...            147
# 32                            CLO                       EBIRD_PR  EOD - eBird Observation Da...              6
# 33                            CLO                      EBIRD_PRY  EOD - eBird Observation Da...              1
# 34                            CLO                       EBIRD_QC  EOD - eBird Observation Da...            153
# 35                            CLO                      EBIRD_TWN  EOD - eBird Observation Da...              3
# 36                            CLO                       EBIRD_TX  EOD - eBird Observation Da...           8893
# 37                            CLO                       EBIRD_VA  EOD - eBird Observation Da...           1667
# 38                            CLO                     EBIRD_VINS  EOD - eBird Observation Da...            453
# 39                            CLO                       EBIRD_WI  EOD - eBird Observation Da...           1336
# 40                            CLO                           GBBC      Great Backyard Bird Count              1
# 41                            CLO                             ML  Macaulay Library Audio and...             47
# 42                           CUMV                           Bird           CUMV Bird Collection              8
# 43                           DMNH                           Bird                     DMNH Birds              2
# 44                           DMNS                 Bird specimens  DMNS Bird Collection (Arctos)              7
# 45                           FMNH                          Birds  Field Museum of Natural Hi...             43
# 46                             KU                          Birds    KUBI Ornithology Collection             16
# 47                           LACM                          Birds     LACM Vertebrate Collection              3
# 48                            MCZ                            Orn  Museum of Comparative Zool...              6
# 49                            MLZ                 Bird specimens   MLZ Bird Collection (Arctos)              1
# 50                           MMNH                           Bird              Bell Museum birds              1
# 51                            MSB                 Bird specimens   MSB Bird Collection (Arctos)              4
# 52                            MVZ                 Bird specimens   MVZ Bird Collection (Arctos)              1
# 53                           OMNH                          Birds                Birds Specimens              3
# 54                           OMNH                           OCGR              Tissues Specimens             14
# 55  Ohio State University - Bi...                          Birds  Ohio State University Tetr...              4
# 56                           PRBO                        PRBO-PC  Point Reyes Bird Observato...              7
# 57                          SBMNH                             AV       SBMNH Vertebrate Zoology              2
# 58                          SDNHM                          Birds         SDNHM Birds Collection              2
# 59                           TCWC                          Birds  Biodiversity Research and ...             19
# 60                           UMMZ                          birds  University of Michigan Mus...             50
# 61                           UWBM                           Bird    UWBM Ornithology Collection              7
# 62                          UWYMV                 Bird specimens  UWYMV Bird Collection (Arc...              1
# 63                            VCE                          VBBA2  The Second Breeding Bird A...             95
# 64                            YPM                             VZ  Vertebrate Zoology Divisio...              3
# 65                    iNaturalist                   Observations  iNaturalist Research-grade...           1183
# 66                    naturgucker                    naturgucker                    naturgucker             31

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#          basisOfRecord   count
# 0    HUMAN_OBSERVATION  457198
# 1  MACHINE_OBSERVATION      47
# 2          OBSERVATION      14
# 3   PRESERVED_SPECIMEN     223

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#          basisOfRecord   count
# 0    HUMAN_OBSERVATION  457139
# 1  MACHINE_OBSERVATION      47
# 2          OBSERVATION      14
# 3   PRESERVED_SPECIMEN     217

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
#          samplingProtocol  count
# 0                Atlasing     72
# 1           Block-busting      3
# 2              Casual Obs     18
# 3             Point Count      2
# 4                 Salvage      2
# 5                    Shot      2
# 6                 Shotgun      4
# 7          none specified      6
# 8                 salvage      9
# 9   salvage-window strike      2
# 10               salvaged      2
# 11            window kill      1

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#          samplingProtocol   count
# 0                    None  457297
# 1                Atlasing      72
# 2           Block-busting       3
# 3              Casual Obs      18
# 4             Point Count       2
# 5                 Salvage       2
# 6                    Shot       2
# 7                 Shotgun       4
# 8          none specified       6
# 9                 salvage       6
# 10  salvage-window strike       2
# 11               salvaged       2
# 12            window kill       1

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                             issues   count
# 0                                                               COORDINATE_ROUNDED  365862
# 1      COORDINATE_ROUNDED;COUNTRY_COORDINATE_MISMATCH;GEODETIC_DATUM_ASSUMED_WGS84       1
# 2                                  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84    1030
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METER...       3
# 4           COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       1
# 5                                                      COUNTRY_COORDINATE_MISMATCH       1
# 6                                                     GEODETIC_DATUM_ASSUMED_WGS84     329
# 7                                        RECORDED_DATE_MISMATCH;COORDINATE_ROUNDED       2

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                                                             issues   count
# 0                                                                                    90253
# 1                                                               COORDINATE_ROUNDED  365858
# 2                                  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84     975
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METER...       3
# 4           COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       1
# 5                                                      COUNTRY_COORDINATE_MISMATCH       1
# 6                                                     GEODETIC_DATUM_ASSUMED_WGS84     324
# 7                                        RECORDED_DATE_MISMATCH;COORDINATE_ROUNDED       2

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)
# Out:
# T:/Code/Wildlife-Wrangler\repo_functions.py:42: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   height=3200000, width=5000000)
# T:/Code/Wildlife-Wrangler\repo_functions.py:44: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawstates(color='grey')
# T:/Code/Wildlife-Wrangler\repo_functions.py:45: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawcountries(color='grey')
# T:/Code/Wildlife-Wrangler\repo_functions.py:56: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   color=mapfile['linecolor'])

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty - Zoomed In")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty - Zoomed In')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# NATIVE, nan

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# A, nan

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                  attribute  included(n)  populated(n)
# Field
# 0                                 abstract       457482             0
# 1                             accessRights       457482           172
# 2                            accrualMethod       457482             0
# 3                       accrualPeriodicity       457482             0
# 4                            accrualPolicy       457482             0
# 5                              alternative       457482             0
# 6                                 audience       457482             0
# 7                                available       457482             0
# 8                    bibliographicCitation       457482           128
# 9                               conformsTo       457482             0
# 10                             contributor       457482             0
# 11                                coverage       457482             0
# 12                                 created       457482             0
# 13                                 creator       457482             0
# 14                                    date       457482             0
# 15                            dateAccepted       457482             0
# 16                         dateCopyrighted       457482             0
# 17                           dateSubmitted       457482             0
# 18                             description       457482             0
# 19                          educationLevel       457482             0
# 20                                  extent       457482             0
# 21                                  format       457482             0
# 22                               hasFormat       457482             0
# 23                                 hasPart       457482             0
# 24                              hasVersion       457482             0
# 25                              identifier       457482        457451
# 26                     instructionalMethod       457482             0
# 27                              isFormatOf       457482             0
# 28                                isPartOf       457482             0
# 29                          isReferencedBy       457482             0
# 30                            isReplacedBy       457482             0
# 31                            isRequiredBy       457482             0
# 32                             isVersionOf       457482             0
# 33                                  issued       457482             0
# 34                                language       457482           203
# 35                                 license       457482        457482
# 36                                mediator       457482             0
# 37                                  medium       457482             0
# 38                                modified       457482          1453
# 39                              provenance       457482             0
# 40                               publisher       457482        457482
# 41                              references       457482          1591
# 42                                relation       457482             0
# 43                                replaces       457482             0
# 44                                requires       457482             0
# 45                                  rights       457482          1290
# 46                            rightsHolder       457482          1413
# 47                                  source       457482             0
# 48                                 spatial       457482             0
# 49                                 subject       457482             0
# 50                         tableOfContents       457482             0
# 51                                temporal       457482             0
# 52                                   title       457482             0
# 53                                    type       457482           292
# 54                                   valid       457482             0
# 55                           institutionID       457482           190
# 56                            collectionID       457482           134
# 57                               datasetID       457482            43
# 58                         institutionCode       457482        457363
# 59                          collectionCode       457482        457481
# 60                             datasetName       457482        457482
# 61                    ownerInstitutionCode       457482           147
# 62                           basisOfRecord       457482        457482
# 63                     informationWithheld       457482            43
# 64                     dataGeneralizations       457482            44
# 65                       dynamicProperties       457482           111
# 66                            occurrenceID       457482        457423
# 67                           catalogNumber       457482        457481
# 68                            recordNumber       457482           105
# 69                              recordedBy       457482        457409
# 70                         individualCount       457482        428390
# 71                        organismQuantity       457482             0
# 72                    organismQuantityType       457482             0
# 73                                     sex       457482           189
# 74                               lifeStage       457482            32
# 75                   reproductiveCondition       457482            20
# 76                                behavior       457482           257
# 77                      establishmentMeans       457482           120
# 78                        occurrenceStatus       457482           216
# 79                            preparations       457482           217
# 80                             disposition       457482            19
# 81                    associatedReferences       457482             0
# 82                     associatedSequences       457482             0
# 83                          associatedTaxa       457482            85
# 84                     otherCatalogNumbers       457482            75
# 85                       occurrenceRemarks       457482           538
# 86                              organismID       457482            64
# 87                            organismName       457482             0
# 88                           organismScope       457482             0
# 89                   associatedOccurrences       457482             3
# 90                     associatedOrganisms       457482             0
# 91                 previousIdentifications       457482            24
# 92                         organismRemarks       457482             9
# 93                        materialSampleID       457482             0
# 94                                 eventID       457482             0
# 95                           parentEventID       457482             0
# 96                             fieldNumber       457482           120
# 97                               eventDate       457482        457482
# 98                               eventTime       457482          1198
# 99                          startDayOfYear       457482           263
# 100                           endDayOfYear       457482           234
# 101                                   year       457482        457482
# 102                                  month       457482        457482
# 103                                    day       457482        457479
# 104                      verbatimEventDate       457482          1507
# 105                                habitat       457482             6
# 106                       samplingProtocol       457482           123
# 107                         samplingEffort       457482             0
# 108                        sampleSizeValue       457482             0
# 109                         sampleSizeUnit       457482             0
# 110                             fieldNotes       457482           121
# 111                           eventRemarks       457482             7
# 112                             locationID       457482             0
# 113                      higherGeographyID       457482             0
# 114                        higherGeography       457482           247
# 115                              continent       457482           265
# 116                              waterBody       457482             4
# 117                            islandGroup       457482             0
# 118                                 island       457482             8
# 119                            countryCode       457482        457482
# 120                          stateProvince       457482        457332
# 121                                 county       457482        455938
# 122                           municipality       457482             3
# 123                               locality       457482        456236
# 124                       verbatimLocality       457482          1466
# 125                      verbatimElevation       457482           185
# 126                          verbatimDepth       457482             0
# 127    minimumDistanceAboveSurfaceInMeters       457482             0
# 128    maximumDistanceAboveSurfaceInMeters       457482             0
# 129                    locationAccordingTo       457482            21
# 130                        locationRemarks       457482           139
# 131                        decimalLatitude       457482        457482
# 132                       decimalLongitude       457482        457482
# 133          coordinateUncertaintyInMeters       457482          1236
# 134                    coordinatePrecision       457482             0
# 135                  pointRadiusSpatialFit       457482             0
# 136               verbatimCoordinateSystem       457482            28
# 137                            verbatimSRS       457482             0
# 138                           footprintWKT       457482            95
# 139                           footprintSRS       457482             0
# 140                    footprintSpatialFit       457482             0
# 141                        georeferencedBy       457482            76
# 142                      georeferencedDate       457482            77
# 143                   georeferenceProtocol       457482           143
# 144                    georeferenceSources       457482           109
# 145         georeferenceVerificationStatus       457482           198
# 146                    georeferenceRemarks       457482           110
# 147                    geologicalContextID       457482             0
# 148            earliestEonOrLowestEonothem       457482             0
# 149             latestEonOrHighestEonothem       457482             0
# 150             earliestEraOrLowestErathem       457482             0
# 151              latestEraOrHighestErathem       457482             0
# 152           earliestPeriodOrLowestSystem       457482             0
# 153            latestPeriodOrHighestSystem       457482             0
# 154            earliestEpochOrLowestSeries       457482             0
# 155             latestEpochOrHighestSeries       457482             0
# 156               earliestAgeOrLowestStage       457482             0
# 157                latestAgeOrHighestStage       457482             0
# 158             lowestBiostratigraphicZone       457482             0
# 159            highestBiostratigraphicZone       457482             0
# 160                lithostratigraphicTerms       457482             0
# 161                                  group       457482             0
# 162                              formation       457482             0
# 163                                 member       457482             0
# 164                                    bed       457482             0
# 165                       identificationID       457482          1237
# 166                identificationQualifier       457482            21
# 167                             typeStatus       457482             0
# 168                           identifiedBy       457482            29
# 169                         dateIdentified       457482          1264
# 170               identificationReferences       457482             0
# 171       identificationVerificationStatus       457482            21
# 172                  identificationRemarks       457482            22
# 173                                taxonID       457482          1243
# 174                       scientificNameID       457482             6
# 175                    acceptedNameUsageID       457482        457482
# 176                      parentNameUsageID       457482             0
# 177                    originalNameUsageID       457482             0
# 178                      nameAccordingToID       457482             0
# 179                      namePublishedInID       457482             0
# 180                         taxonConceptID       457482             0
# 181                         scientificName       457482        457482
# 182                      acceptedNameUsage       457482             0
# 183                        parentNameUsage       457482             0
# 184                      originalNameUsage       457482             0
# 185                        nameAccordingTo       457482             0
# 186                        namePublishedIn       457482             0
# 187                    namePublishedInYear       457482             0
# 188                   higherClassification       457482           318
# 189                                kingdom       457482        457482
# 190                                 phylum       457482        457482
# 191                                  class       457482        457482
# 192                                  order       457482        457482
# 193                                 family       457482        457482
# 194                                  genus       457482        457482
# 195                               subgenus       457482             0
# 196                        specificEpithet       457482        457479
# 197                   infraspecificEpithet       457482           120
# 198                              taxonRank       457482        457482
# 199                      verbatimTaxonRank       457482             0
# 200                         vernacularName       457482           287
# 201                      nomenclaturalCode       457482           311
# 202                        taxonomicStatus       457482        457482
# 203                    nomenclaturalStatus       457482             0
# 204                           taxonRemarks       457482             3
# 205                             datasetKey       457482        457482
# 206                      publishingCountry       457482        457482
# 207                        lastInterpreted       457482        457482
# 208                              elevation       457482            32
# 209                      elevationAccuracy       457482            20
# 210                                  depth       457482             0
# 211                          depthAccuracy       457482             0
# 212                   distanceAboveSurface       457482             0
# 213           distanceAboveSurfaceAccuracy       457482             0
# 214                                  issue       457482        367229
# 215                              mediaType       457482          1213
# 216                          hasCoordinate       457482        457482
# 217                    hasGeospatialIssues       457482        457482
# 218                               taxonKey       457482        457482
# 219                       acceptedTaxonKey       457482        457482
# 220                             kingdomKey       457482        457482
# 221                              phylumKey       457482        457482
# 222                               classKey       457482        457482
# 223                               orderKey       457482        457482
# 224                              familyKey       457482        457482
# 225                               genusKey       457482        457482
# 226                            subgenusKey       457482             0
# 227                             speciesKey       457482        457482
# 228                                species       457482        457482
# 229                            genericName       457482        457479
# 230                 acceptedScientificName       457482        457482
# 231                 verbatimScientificName       457482             0
# 232                           typifiedName       457482        457482
# 233                               protocol       457482        457482
# 234                             lastParsed       457482        457482
# 235                            lastCrawled       457482        457482
# 236                            repatriated       457482             0
# 237               relativeOrganismQuantity       457482             4
# 238                           recordedByID       457482             5
# 239                         identifiedByID       457482             0

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:22:49.194054
