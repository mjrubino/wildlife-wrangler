# %% [markdown]
# # Canyon Treefrog Occurrence Records Summary
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### General Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
#import geopandas as gpd
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import repo_functions as functions

# %% [markdown]
# ### Set Variables
# Fill out stuff in this cell.

# %%
species_id = 'acytrx0'
summary_name = 'TWStreefrog'
gbif_req_id = 'GBIFr15'
gbif_filter_id = 'GBIFf6'
workDir = '/Users/nmtarr/Documents/Occurrence_Records/'
codeDir = '/Users/nmtarr/Code/occurrence-records-wrangler/'
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
default_coordUncertainty = 500
SRID_dict = {'WGS84': 4326, 'AlbersNAD83': 102008} # Used in file names for output.
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'

print("Notebook run " + str(t1))
# Out:
# Notebook run 2019-08-28 20:49:13.835244

# %%
connjup = sqlite3.connect(codeDir + 'parameters.sqlite')
cursorjup = connjup.cursor()

# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'breeding_months': '',
#  'common_name': 'canyon treefrog',
#  'detection_distance_meters': 0,
#  'end_year': '',
#  'error_tolerance': 20,
#  'fws_id': 'Hyla arenicolor',
#  'gap_id': 'acytrx',
#  'gbif_id': '2427572',
#  'geometry': '',
#  'itis_tsn': '173510',
#  'migratory': '0',
#  'notes': '',
#  'pad': 1,
#  'scientific_name': 'Hyla arenicolor',
#  'species_id': 'acytrx0',
#  'start_year': '',
#  'wintering_months': ''}

# %% [markdown]
# ## Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                                                    GBIFr15
# source                                                           GBIF
# lat_range                                                       27,41
# lon_range                                                     -91,-75
# years_range                                                 1999,2020
# months_range                                                     1,12
# geoissue                                                        False
# coordinate                                                       True
# continent                                                        None
# creator                                                       N. Tarr
# notes           For updating  GAP range maps.  Are the years correct?
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                                                          GBIFf6
# dataset                                                                              GBIF
# collection_codes_omit                                                                None
# institutions_omit                                                                    None
# has_coordinate_uncertainty                                                              0
# max_coordinate_uncertainty                                                           5000
# bases_omit                                            PRESERVED_SPECIMEN, FOSSIL_SPECIMEN
# protocols_omit                                                                       None
# sampling_protocols_omit                                                              None
# issues_omit                   GEODETIC_DATUM_INVALID, INDIVIDUAL_COUNT_INVALID, MULTIM...
# creator                                                                           N. Tarr
# notes                                                             For TWS 2019 talk demo.
# Name: 0, dtype: object

# %% [markdown]
# ### Filter set justification
# default_coord_uncertainty: Records unlikely to be from transects with rounded coordinates for this species so kept default to something seemingly modest.
#
# years_range: I wanted a good number of records
#
# months_range: All seasons are of interest for this non-migratory species.
#
# geoissue: Such issues would introduce known errors.
#
# coordinate: Required for desired evaluation.
#
# continent: This field doesn't work well.
#
# collection_codes_omit: No known reason to omit any.
#
# institutions_omit: No known reason to omit any.
#
# has_coordinate_uncertainty: Not used in order to maximize records
#
# max_coordinate_uncertainty: Evaluation will handle coordinate uncertainty
#
# bases_omit: No reason to omit any.
#
# protocols_omit:  No reason to omit.
#
# sampling_protocols_omit: No reason to omit.
#
# issues_omit:  These issues would likely introduce problematic errors.

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, inDir, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, SRID_dict, outDir, summary_name)
# Out:
# relaxed
# downloading https://www.sciencebase.gov/catalog/file/get/59f5e29fe4b063d5d307dfab?f=__disk__95%2F4e%2F9d%2F954e9d28eb598bb17e4bc8c803f7b748a2e650bc to /Users/nmtarr/Documents/Occurrence_Records/Inputs/aCYTRx_CONUS_Range_2001v1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/59f5e29fe4b063d5d307dfab?f=__disk__ec%2Fe7%2Fe4%2Fece7e4d55e30514670a82b61b3728f042b5ae541 to /Users/nmtarr/Documents/Occurrence_Records/Inputs/aCYTRx_CONUS_Range_2001v1.xml
# /Users/nmtarr/Documents/Occurrence_Records/Outputs/acytrx0GBIFr15GBIFf6.sqlite
#
# 1774 records exist with the request parameters
#
# There was a problem with the following record:
# near "t": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'acceptedTaxonKey': 2427572, 'scientificName': 'Hyla arenicolor Cope, 1866', 'acceptedScientificName': 'Hyla arenicolor Cope, 1866', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -106.214391, 'decimalLatitude': 35.620632, 'coordinateUncertaintyInMeters': 1802.0, 'year': 2018, 'month': 9, 'day': 14, 'eventDate': '2018-09-14T20:42:00', 'issues': ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84'], 'geodeticDatum': 'WGS84', 'gbifID': '1913687937', 'collectionCode': 'Observations', 'occurrenceID': 'https://www.inaturalist.org/observations/16615932', 'institutionCode': 'iNaturalist', 'occurrenceRemarks': 'CORRECTED to Canyon Tree Frog! Thank you! --Possibly Woodhouse Toad but it didn\'t have the stripe down the back and the pupils appear round not vertical, but maybe it isn\'t full developed. Size 1.5". Found at natural pond on the Santa Fe National Forest.', 'remarks': 'CORRECTED to Canyon Tree Frog! Thank you! --Possibly Woodhouse Toad but it didn\'t have the stripe down the back and the pupils appear round not vertical, but maybe it isn\'t full developed. Size 1.5". Found at natural pond on the Santa Fe National Forest.', 'dataGeneralizations': ''}
#
# Records saved in /Users/nmtarr/Documents/Occurrence_Records/Outputs/acytrx0GBIFr15GBIFf6.sqlite

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 1120 records

# %% [markdown]
# ### Were there duplicate records?
# needs to be addressed

# %%
dups0 = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences GROUP BY geom_xy4326, occurrenceDate;").fetchall()
dups1 = [x[0] for x in dups0]
dups2 = [x for x in dups1 if x > 1]
print(str(len(dups2)) + ' records were duplicates based on xy coordinate and date-time')
# Out:
# 29 records were duplicates based on xy coordinate and date-time

# %% [markdown]
# # Institutions
# #### Pre-filters

# %%
institutions = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'institutions';").fetchall()
for x in institutions:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# iNaturalist (1027)
# MSB (41)
# 49 (37)
# UTEP (9)
# http://biocol.org/urn:lsid:biocol.org:col:34871 (2)
# 68 (522)
# 2027 (34)
# 20 (22)
# MVZ (6)
# http://biocol.org/urn:lsid:biocol.org:col:34852 (8)
# 17 (1)
# 1849 (37)
# http://grbio.org/cool/5bc7-5n0c (2)
# 1932 (2)
# YPM (1)
# urn:lsid:biocol.org:col:34844 (3)
# 1884 (1)
# OMNH (4)
# 1885 (3)
# UCM (11)
# 558 (1)

# %% [markdown]
# #### Post-filter

# %%
institutions = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'institutions' AND step = 'filter';").fetchone()[0]
institutions = institutions.replace('[', '').strip().replace(']', '').replace("'", "")
institutions = institutions.split(',')
for ins in institutions:
    print(ins.strip())
# Out:
# ENCB-IPN
# IE-UNAM
# FESI-UNAM
# iNaturalist
# CIB-UAEM

# %% [markdown]
# # Collections
# #### Pre-filters

# %%
collections = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'collections';").fetchall()
for x in collections:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# Observations (1027)
# Amphibian and reptile specimens (67)
# NO APLICA (230)
# Amphibians & Reptiles (2)
# ENCB (34)
# CNAR (22)
# Herpetology (11)
# CIB-UAEH (37)
# HERP (2)
# MZFC (2)
# VZ (1)
# OCGR (2)
# Amphibians (2)
# UABC (3)
# LE-UBIPRO (327)
# MVZ (1)
# CARUM (4)

# %% [markdown]
# #### Post-filters

# %%
collections = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'collections' AND step = 'filter';").fetchone()[0]
collections = collections.replace('[', '').strip().replace(']', '').replace("'", "")
collections = collections.split(',')
for colls in collections:
    print(colls.strip())
# Out:
# Observations
# NO APLICA

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'bases';").fetchall()
for x in bases:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# HUMAN_OBSERVATION (1257)
# PRESERVED_SPECIMEN (517)

# %% [markdown]
# #### Post-filters

# %%
bases = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'bases' AND step = 'filter';").fetchone()[0]
bases = bases.replace('[', '').strip().replace(']', '').replace("'", "")
bases = bases.split(",")
for bas in bases:
    print(bas.strip())
# Out:
# HUMAN_OBSERVATION

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocols = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'protocols';").fetchall()
for x in protocols:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# DWC_ARCHIVE (1774)

# %% [markdown]
# #### Post-filters

# %%
protos = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'protocols' AND step = 'filter';").fetchall()[0]
for pro in protos:
    pro = pro.replace('[', '').strip().replace(']', '').replace("'", "")
    print(pro)
# Out:
# DWC_ARCHIVE

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
issues = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'issues';").fetchall()
for x in issues:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# COORDINATE_ROUNDED (1482)
# GEODETIC_DATUM_ASSUMED_WGS84 (1577)
# COORDINATE_UNCERTAINTY_METERS_INVALID (3)
# GEODETIC_DATUM_INVALID (523)
# TAXON_MATCH_HIGHERRANK (661)
# ELEVATION_MIN_MAX_SWAPPED (217)
# COORDINATE_REPROJECTED (25)
# COUNTRY_DERIVED_FROM_COORDINATES (3)

# %% [markdown]
# #### Post-filters

# %%
issues = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'issues' AND step = 'filter';").fetchone()[0]
issues = issues.replace('[', '').strip().replace(']', '').replace("'", "")
issues = issues.split(',')
for iss in issues:
    print(iss.strip())
# Out:
# COORDINATE_ROUNDED
# GEODETIC_DATUM_INVALID
# COORDINATE_UNCERTAINTY_METERS_INVALID
# TAXON_MATCH_HIGHERRANK
# ELEVATION_MIN_MAX_SWAPPED
# GEODETIC_DATUM_ASSUMED_WGS84

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
gap_range2 = "{0}{1}_range_4326".format(inDir, gap_id)

shp1 = {'file': gap_range2, 'column': None, 'alias': 'GAP range map',
        'drawbounds': False, 'linewidth': .5, 'linecolor': 'y',
        'fillcolor': 'y', 'marker':'s'}

shp2 = {'file': '{0}{1}_circles'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
if os.path.isfile(gap_range2 + ".shp"):
    map_these=[shp1, shp2]
else:
    map_these=[shp2]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of occurrences")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of occurrences")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %% [markdown]
# ### Geodetic datums present

# %%
datums = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'datums' AND step = 'filter';").fetchone()[0]
datums = datums.replace('[', '').strip().replace(']', '').replace("'", "")
datums = datums.split()
for datum in datums:
    print(datum)
# Out:
# WGS84

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM record_attributes WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
#remarks = remarks.replace('[', '').strip().replace(']', '').replace("'", "")
#remarks = remarks.split(',')
if len(remarks) <= 20:
    for rem in remarks:
        if rem[0][0:1] == ';':
            print(rem[0][2:])
        else:
            print(rem[0])
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Sources

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])
# Out:
# GBIF

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ, index_col='index')
fields_summary.index.name = 'field'
print(fields_summary)
# Out:
#                                       included(n)  populated(n)
# field
# acceptedNameUsage                             660           660
# acceptedScientificName                       1774          1774
# acceptedTaxonKey                             1774          1774
# accessRights                                  741           741
# associatedReferences                            1             1
# basisOfRecord                                1774          1774
# bibliographicCitation                         664           664
# catalogNumber                                1774          1774
# class                                        1774          1774
# classKey                                     1774          1774
# collectionCode                               1774          1774
# collectionID                                  740           740
# continent                                      83            83
# coordinateUncertaintyInMeters                 869           869
# country                                      1774          1774
# countryCode                                  1774          1774
# county                                        727           727
# crawlId                                      1774          1774
# datasetID                                     660           660
# datasetKey                                   1774          1774
# datasetName                                  1691          1691
# dateIdentified                               1011          1011
# day                                          1774          1774
# decimalLatitude                              1774          1774
# decimalLongitude                             1774          1774
# depth                                         660           660
# depthAccuracy                                 660           660
# dynamicProperties                             707           707
# elevation                                     708           708
# elevationAccuracy                             707           707
# endDayOfYear                                  604           604
# establishmentMeans                             13            13
# eventDate                                    1774          1774
# eventRemarks                                    9             9
# eventTime                                     979           979
# extensions                                   1774             0
# facts                                        1774             0
# family                                       1774          1774
# familyKey                                    1774          1774
# fieldNumber                                   662           662
# gbifID                                       1774          1774
# genericName                                  1774          1774
# genus                                        1774          1774
# genusKey                                     1774          1774
# geodeticDatum                                1774          1774
# georeferenceProtocol                           67            67
# georeferenceSources                           725           725
# georeferenceVerificationStatus                 82            82
# georeferencedBy                                68            68
# georeferencedDate                              67            67
# habitat                                       647           647
# higherClassification                          743           743
# higherGeography                                83            83
# http://unknown.org/nick                      1027          1027
# http://unknown.org/occurrenceDetails         1027          1027
# http://unknown.org/recordedByOrcid              6             6
# identificationID                             1613          1613
# identificationQualifier                        67            67
# identificationRemarks                           2             2
# identificationVerificationStatus               67            67
# identifiedBy                                  728           728
# identifier                                   1774          1774
# identifiers                                  1774             0
# individualCount                               728           728
# informationWithheld                            99            99
# installationKey                              1774          1774
# institutionCode                              1774          1774
# institutionID                                 742           742
# issues                                       1774          1756
# key                                          1774          1774
# kingdom                                      1774          1774
# kingdomKey                                   1774          1774
# language                                      745           745
# lastCrawled                                  1774          1774
# lastInterpreted                              1774          1774
# lastParsed                                   1774          1774
# license                                      1774          1774
# lifeStage                                      67            67
# locality                                      747           747
# locationAccordingTo                            67            67
# locationID                                    660           660
# locationRemarks                                 6             6
# media                                         940           940
# modified                                     1770          1770
# month                                        1774          1774
# nameAccordingTo                               660           660
# namePublishedIn                                75            75
# namePublishedInYear                           660           660
# networkKeys                                  1774            67
# nomenclaturalCode                              81            81
# occurrenceID                                 1774          1774
# occurrenceRemarks                             845           845
# occurrenceStatus                               13            13
# order                                        1774          1774
# orderKey                                     1774          1774
# organismID                                     67            67
# otherCatalogNumbers                            59            59
# ownerInstitutionCode                          661           661
# parentNameUsage                               660           660
# phylum                                       1774          1774
# phylumKey                                    1774          1774
# preparations                                  701           701
# previousIdentifications                        72            72
# protocol                                     1774          1774
# publishingCountry                            1774          1774
# publishingOrgKey                             1774          1774
# recordNumber                                   51            51
# recordedBy                                   1771          1771
# references                                   1108          1108
# relations                                    1774             0
# reproductiveCondition                           4             4
# rights                                       1027          1027
# rightsHolder                                 1688          1688
# scientificName                               1774          1774
# scientificNameID                              660           660
# sex                                             7             7
# species                                      1774          1774
# speciesKey                                   1774          1774
# specificEpithet                              1774          1774
# startDayOfYear                                675           675
# stateProvince                                1773          1773
# taxonID                                      1687          1687
# taxonKey                                     1774          1774
# taxonRank                                    1774          1774
# taxonRemarks                                    1             1
# taxonomicStatus                              1774          1774
# type                                          743           743
# typeStatus                                      4             4
# verbatimCoordinateSystem                      726           726
# verbatimElevation                               1             1
# verbatimEventDate                            1107          1107
# verbatimLocality                             1107          1107
# vernacularName                                671           671
# year                                         1774          1774

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:02:34.276617
