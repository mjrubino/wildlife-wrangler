# %% [markdown]
# # DOWO BIG TEST
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### Set Variables
# Fill out stuff in this cell.
#
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
species_id = 'bdowox1'
summary_name = 'dowobig'
gbif_req_id = 'GBIFr25'
gbif_filter_id = 'GBIFf10'
default_coordUncertainty = 1000       # Note above.
workDir = 'T:/Occurrence_Records/'   # Be sure to create folders named "Inputs" and "Outputs" here.
codeDir = 'T:/Code/wildlife-wrangler/'
paramdb = 'P:/Proj3/USGap/Vert/DBase/wildlife-wrangler.sqlite'
configDir = 'T:/GAP/Data/'  # Path to folder where saved your wildlifeconfig file.

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temp fix, hopefully.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410

# %%
import os
os.environ['PROJ_LIB'] = r'c:\Users\nmtarr\AppData\Local\Continuum\miniconda3\envs\wrangler\Library\share'

# %% [markdown]
# ### Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
sys.path.append(codeDir)
import repo_functions as functions
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
# Out:
# Notebook run 2020-03-18 10:17:00.986012
# T:/Occurrence_Records/Outputs/bdowox1GBIFr25GBIFf10.sqlite

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'common_name': 'downy woodpecker',
#  'detection_distance_meters': 200,
#  'ebird_id': None,
#  'end_year': None,
#  'fws_id': None,
#  'gap_id': None,
#  'gbif_id': '9149595',
#  'geometry': None,
#  'itis_tsn': None,
#  'lumped_into': None,
#  'notes': 'Birdlife was using Dryobates as early as 2014.',
#  'scientific_name': 'Dryobates pubescens',
#  'species_id': 'bdowox1',
#  'split_from': 'bdowox0',
#  'start_year': 2018,
#  'vetted_date': '3/10/2020',
#  'vetted_how': 'Consulted avibase.',
#  'vetted_who': 'N. Tarr'}

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                            GBIFr25
# source                                   GBIF
# lat_range                               27,41
# lon_range                             -91,-75
# years_range                         2015,2020
# months_range                             1,12
# geoissue                                False
# coordinate                               True
# country                                    US
# geometry                                 None
# creator                               N. Tarr
# notes           Built for GAP v2 range map...
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                           GBIFf10
# dataset                                                GBIF
# institutions_omit                                      None
# collection_codes_omit                                  None
# datasets_omit                                          None
# has_coordinate_uncertainty                                0
# max_coordinate_uncertainty                             5000
# bases_omit                                  FOSSIL_SPECIMEN
# sampling_protocols_omit                                None
# issues_omit                          TAXON_MATCH_HIGHERRANK
# duplicates_OK                                          True
# creator                                             N. Tarr
# notes                         For use in creating GAP ve...
# Name: 0, dtype: object

# %% [markdown]
# ## Filter set justification
# Enter your justification for the following settings.
#
# **default_coord_uncertainty:**
#
# **years_range:**
#
# **months_range:**
#
# **geoissue:**
#
# **coordinate:**
#
# **country:**
#
# **geometry:**
#
# **collection_codes_omit:**
#
# **institutions_omit:**
#
# **datasets_omit:**
#
# **has_coordinate_uncertainty:**
#
# **max_coordinate_uncertainty:**
#
# **bases_omit:**
#
# **sampling_protocols_omit:**
#
# **issues_omit:**
#
# **duplicates:**

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, inDir, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                   password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.360404
# Got request params and sorted out geometry constraints: 0:00:00.002996
# 1135091 records available
# Your download key is  0023193-200221144449610
# Downloading Darwin Core Archive zip file for this species .....
# Download file size: 245976633 bytes
# On disk at T:/Occurrence_Records/Inputs//0023193-200221144449610.zip
# Download complete: 0:07:53.941450
# Downloaded and loaded records: 0:00:56.212134
# Summarized fields returned: 0:00:03.288003
# Created summary table of request results: 0:00:00.826351
# Performed post-request filtering: 0:00:01.789702
# Calculated new columns, deleted some too: 0:00:01.865268
# Inserted records into table: 0:00:24.671576
# Summarized unique values retained: 0:00:00.253116
# Updated occurrences table geometry column: 0:05:32.739854
# DUPLICATES ON LATITUDE, LONGITUDE, DATE-TIME INCLUDED
# Buffered points: 0:11:24.356916
# Exported maps: 0:04:48.123305
#
# Records saved in T:/Occurrence_Records/Outputs/bdowox1GBIFr25GBIFf10.sqlite

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 1134629 records

# %% [markdown]
# ### Are there duplicate records left?
# NOTE:  DUPLICATE HANDLING MAY NOT BE PERFORMING CORRECTLY.
# Duplicates based on latitude, longitude, and date-time should have been removed, with the record with the highest individualCount retained.

# %%
dups0 = curs_occ.execute("""SELECT count(occ_id) FROM occurrences WHERE occ_id NOT IN (SELECT occ_id FROM occurrences GROUP BY latitude, longitude, occurrenceDate HAVING max(IndividualCount));""").fetchall()
print(str(dups0[0][0]) + ' duplicate records retained based on xy coordinate and date-time')
# Out:
# 237342 duplicate records retained based on xy coordinate and date-time

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode  collectionCode                    datasetName        0
# 0              CLO           EBIRD  EOD - eBird Observation Da...  1068057
# 1              CLO        EBIRD_AK  EOD - eBird Observation Da...      204
# 2              CLO       EBIRD_ARG  EOD - eBird Observation Da...        7
# 3              CLO        EBIRD_AU  EOD - eBird Observation Da...       36
# 4              CLO       EBIRD_BCN  EOD - eBird Observation Da...      156
# 5              CLO       EBIRD_BRA  EOD - eBird Observation Da...       22
# 6              CLO  EBIRD_CAMERICA  EOD - eBird Observation Da...      168
# 7              CLO       EBIRD_CAN  EOD - eBird Observation Da...      510
# 8              CLO        EBIRD_CB  EOD - eBird Observation Da...       21
# 9              CLO        EBIRD_CL  EOD - eBird Observation Da...       69
# 10             CLO       EBIRD_ESP  EOD - eBird Observation Da...        3
# 11             CLO      EBIRD_GBBC  EOD - eBird Observation Da...    39522
# 12             CLO       EBIRD_IND  EOD - eBird Observation Da...       38
# 13             CLO     EBIRD_KIOSK  EOD - eBird Observation Da...       14
# 14             CLO      EBIRD_LWBA  EOD - eBird Observation Da...       11
# 15             CLO        EBIRD_MA  EOD - eBird Observation Da...       46
# 16             CLO        EBIRD_ME  EOD - eBird Observation Da...       92
# 17             CLO       EBIRD_MEX  EOD - eBird Observation Da...      957
# 18             CLO        EBIRD_MO  EOD - eBird Observation Da...      597
# 19             CLO       EBIRD_MYS  EOD - eBird Observation Da...       12
# 20             CLO        EBIRD_NH  EOD - eBird Observation Da...       92
# 21             CLO        EBIRD_NJ  EOD - eBird Observation Da...      776
# 22             CLO        EBIRD_NZ  EOD - eBird Observation Da...        7
# 23             CLO        EBIRD_PA  EOD - eBird Observation Da...    13554
# 24             CLO        EBIRD_PE  EOD - eBird Observation Da...        7
# 25             CLO       EBIRD_PNW  EOD - eBird Observation Da...      182
# 26             CLO        EBIRD_PR  EOD - eBird Observation Da...       25
# 27             CLO        EBIRD_QC  EOD - eBird Observation Da...      218
# 28             CLO       EBIRD_TUR  EOD - eBird Observation Da...        1
# 29             CLO       EBIRD_TWN  EOD - eBird Observation Da...       80
# 30             CLO        EBIRD_TX  EOD - eBird Observation Da...      144
# 31             CLO        EBIRD_VA  EOD - eBird Observation Da...     6177
# 32             CLO      EBIRD_VINS  EOD - eBird Observation Da...      121
# 33             CLO        EBIRD_WI  EOD - eBird Observation Da...      151
# 34     iNaturalist    Observations  iNaturalist Research-grade...     2991
# 35     naturgucker     naturgucker                    naturgucker       11

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode  collectionCode                    datasetName  COUNT(occ_id)
# 0             None     Bird sounds  Xeno-canto - Bird sounds f...             11
# 1              CLO           EBIRD  EOD - eBird Observation Da...        1068057
# 2              CLO        EBIRD_AK  EOD - eBird Observation Da...            204
# 3              CLO       EBIRD_ARG  EOD - eBird Observation Da...              7
# 4              CLO        EBIRD_AU  EOD - eBird Observation Da...             36
# 5              CLO       EBIRD_BCN  EOD - eBird Observation Da...            156
# 6              CLO       EBIRD_BRA  EOD - eBird Observation Da...             22
# 7              CLO  EBIRD_CAMERICA  EOD - eBird Observation Da...            168
# 8              CLO       EBIRD_CAN  EOD - eBird Observation Da...            510
# 9              CLO        EBIRD_CB  EOD - eBird Observation Da...             21
# 10             CLO        EBIRD_CL  EOD - eBird Observation Da...             69
# 11             CLO       EBIRD_ESP  EOD - eBird Observation Da...              3
# 12             CLO      EBIRD_GBBC  EOD - eBird Observation Da...          39522
# 13             CLO       EBIRD_IND  EOD - eBird Observation Da...             38
# 14             CLO     EBIRD_KIOSK  EOD - eBird Observation Da...             14
# 15             CLO      EBIRD_LWBA  EOD - eBird Observation Da...             11
# 16             CLO        EBIRD_MA  EOD - eBird Observation Da...             46
# 17             CLO        EBIRD_ME  EOD - eBird Observation Da...             92
# 18             CLO       EBIRD_MEX  EOD - eBird Observation Da...            957
# 19             CLO        EBIRD_MO  EOD - eBird Observation Da...            597
# 20             CLO       EBIRD_MYS  EOD - eBird Observation Da...             12
# 21             CLO        EBIRD_NH  EOD - eBird Observation Da...             92
# 22             CLO        EBIRD_NJ  EOD - eBird Observation Da...            776
# 23             CLO        EBIRD_NZ  EOD - eBird Observation Da...              7
# 24             CLO        EBIRD_PA  EOD - eBird Observation Da...          13554
# 25             CLO        EBIRD_PE  EOD - eBird Observation Da...              7
# 26             CLO       EBIRD_PNW  EOD - eBird Observation Da...            182
# 27             CLO        EBIRD_PR  EOD - eBird Observation Da...             25
# 28             CLO        EBIRD_QC  EOD - eBird Observation Da...            218
# 29             CLO       EBIRD_TUR  EOD - eBird Observation Da...              1
# 30             CLO       EBIRD_TWN  EOD - eBird Observation Da...             80
# 31             CLO        EBIRD_TX  EOD - eBird Observation Da...            144
# 32             CLO        EBIRD_VA  EOD - eBird Observation Da...           6177
# 33             CLO      EBIRD_VINS  EOD - eBird Observation Da...            121
# 34             CLO        EBIRD_WI  EOD - eBird Observation Da...            151
# 35     iNaturalist    Observations  iNaturalist Research-grade...           2530
# 36     naturgucker     naturgucker                    naturgucker             11

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#        basisOfRecord    count
# 0  HUMAN_OBSERVATION  1135091

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#        basisOfRecord    count
# 0  HUMAN_OBSERVATION  1134629

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
# Empty DataFrame
# Columns: [samplingProtocol, count]
# Index: []

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#   samplingProtocol    count
# 0             None  1134629

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                             issues   count
# 0                                                               COORDINATE_ROUNDED  906044
# 1                                  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84    2627
# 2  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METER...       7
# 3           COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_HIGHERRANK       1
# 4                                                     GEODETIC_DATUM_ASSUMED_WGS84     367
# 5                                                           TAXON_MATCH_HIGHERRANK       1

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                                                             issues   count
# 0                                                                                   226044
# 1                                                               COORDINATE_ROUNDED  906044
# 2                                  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84    2184
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METER...       7
# 4                                                     GEODETIC_DATUM_ASSUMED_WGS84     350

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)
# Out:
# T:/Code/wildlife-wrangler\repo_functions.py:42: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   height=3200000, width=5000000)
# T:/Code/wildlife-wrangler\repo_functions.py:44: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawstates(color='grey')
# T:/Code/wildlife-wrangler\repo_functions.py:45: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawcountries(color='grey')
# T:/Code/wildlife-wrangler\repo_functions.py:56: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   color=mapfile['linecolor'])

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty - Zoomed In")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty - Zoomed In')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# nan

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# nan

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                  attribute  included(n)  populated(n)
# Field
# 0                                 abstract      1135091             0
# 1                             accessRights      1135091             0
# 2                            accrualMethod      1135091             0
# 3                       accrualPeriodicity      1135091             0
# 4                            accrualPolicy      1135091             0
# 5                              alternative      1135091             0
# 6                                 audience      1135091             0
# 7                                available      1135091             0
# 8                    bibliographicCitation      1135091             0
# 9                               conformsTo      1135091             0
# 10                             contributor      1135091             0
# 11                                coverage      1135091             0
# 12                                 created      1135091             0
# 13                                 creator      1135091             0
# 14                                    date      1135091             0
# 15                            dateAccepted      1135091             0
# 16                         dateCopyrighted      1135091             0
# 17                           dateSubmitted      1135091             0
# 18                             description      1135091             0
# 19                          educationLevel      1135091             0
# 20                                  extent      1135091             0
# 21                                  format      1135091             0
# 22                               hasFormat      1135091             0
# 23                                 hasPart      1135091             0
# 24                              hasVersion      1135091             0
# 25                              identifier      1135091       1135080
# 26                     instructionalMethod      1135091             0
# 27                              isFormatOf      1135091             0
# 28                                isPartOf      1135091             0
# 29                          isReferencedBy      1135091             0
# 30                            isReplacedBy      1135091             0
# 31                            isRequiredBy      1135091             0
# 32                             isVersionOf      1135091             0
# 33                                  issued      1135091             0
# 34                                language      1135091             0
# 35                                 license      1135091       1135091
# 36                                mediator      1135091             0
# 37                                  medium      1135091             0
# 38                                modified      1135091          2991
# 39                              provenance      1135091             0
# 40                               publisher      1135091       1135091
# 41                              references      1135091          3003
# 42                                relation      1135091             0
# 43                                replaces      1135091             0
# 44                                requires      1135091             0
# 45                                  rights      1135091          2991
# 46                            rightsHolder      1135091          3003
# 47                                  source      1135091             0
# 48                                 spatial      1135091             0
# 49                                 subject      1135091             0
# 50                         tableOfContents      1135091             0
# 51                                temporal      1135091             0
# 52                                   title      1135091             0
# 53                                    type      1135091             0
# 54                                   valid      1135091             0
# 55                           institutionID      1135091             0
# 56                            collectionID      1135091             0
# 57                               datasetID      1135091             0
# 58                         institutionCode      1135091       1135079
# 59                          collectionCode      1135091       1135091
# 60                             datasetName      1135091       1135091
# 61                    ownerInstitutionCode      1135091             0
# 62                           basisOfRecord      1135091       1135091
# 63                     informationWithheld      1135091           355
# 64                     dataGeneralizations      1135091             0
# 65                       dynamicProperties      1135091             0
# 66                            occurrenceID      1135091       1135080
# 67                           catalogNumber      1135091       1135091
# 68                            recordNumber      1135091             0
# 69                              recordedBy      1135091       1135091
# 70                         individualCount      1135091       1116382
# 71                        organismQuantity      1135091             0
# 72                    organismQuantityType      1135091             0
# 73                                     sex      1135091             0
# 74                               lifeStage      1135091             0
# 75                   reproductiveCondition      1135091             0
# 76                                behavior      1135091            12
# 77                      establishmentMeans      1135091             0
# 78                        occurrenceStatus      1135091             0
# 79                            preparations      1135091             0
# 80                             disposition      1135091             0
# 81                    associatedReferences      1135091             0
# 82                     associatedSequences      1135091             0
# 83                          associatedTaxa      1135091             3
# 84                     otherCatalogNumbers      1135091             0
# 85                       occurrenceRemarks      1135091           491
# 86                              organismID      1135091             0
# 87                            organismName      1135091             0
# 88                           organismScope      1135091             0
# 89                   associatedOccurrences      1135091             0
# 90                     associatedOrganisms      1135091             0
# 91                 previousIdentifications      1135091             0
# 92                         organismRemarks      1135091             0
# 93                        materialSampleID      1135091             0
# 94                                 eventID      1135091             0
# 95                           parentEventID      1135091             0
# 96                             fieldNumber      1135091             0
# 97                               eventDate      1135091       1135091
# 98                               eventTime      1135091          2738
# 99                          startDayOfYear      1135091             0
# 100                           endDayOfYear      1135091             0
# 101                                   year      1135091       1135091
# 102                                  month      1135091       1135091
# 103                                    day      1135091       1135091
# 104                      verbatimEventDate      1135091          3003
# 105                                habitat      1135091             0
# 106                       samplingProtocol      1135091             0
# 107                         samplingEffort      1135091             0
# 108                        sampleSizeValue      1135091             0
# 109                         sampleSizeUnit      1135091             0
# 110                             fieldNotes      1135091            12
# 111                           eventRemarks      1135091             0
# 112                             locationID      1135091             0
# 113                      higherGeographyID      1135091             0
# 114                        higherGeography      1135091             0
# 115                              continent      1135091             0
# 116                              waterBody      1135091             0
# 117                            islandGroup      1135091             0
# 118                                 island      1135091             0
# 119                            countryCode      1135091       1135091
# 120                          stateProvince      1135091       1135068
# 121                                 county      1135091       1132077
# 122                           municipality      1135091             0
# 123                               locality      1135091       1132099
# 124                       verbatimLocality      1135091          2991
# 125                      verbatimElevation      1135091            12
# 126                          verbatimDepth      1135091             0
# 127    minimumDistanceAboveSurfaceInMeters      1135091             0
# 128    maximumDistanceAboveSurfaceInMeters      1135091             0
# 129                    locationAccordingTo      1135091             0
# 130                        locationRemarks      1135091             0
# 131                        decimalLatitude      1135091       1135091
# 132                       decimalLongitude      1135091       1135091
# 133          coordinateUncertaintyInMeters      1135091          2485
# 134                    coordinatePrecision      1135091             0
# 135                  pointRadiusSpatialFit      1135091             0
# 136               verbatimCoordinateSystem      1135091             0
# 137                            verbatimSRS      1135091             0
# 138                           footprintWKT      1135091             0
# 139                           footprintSRS      1135091             0
# 140                    footprintSpatialFit      1135091             0
# 141                        georeferencedBy      1135091             0
# 142                      georeferencedDate      1135091             0
# 143                   georeferenceProtocol      1135091             0
# 144                    georeferenceSources      1135091             0
# 145         georeferenceVerificationStatus      1135091             0
# 146                    georeferenceRemarks      1135091             0
# 147                    geologicalContextID      1135091             0
# 148            earliestEonOrLowestEonothem      1135091             0
# 149             latestEonOrHighestEonothem      1135091             0
# 150             earliestEraOrLowestErathem      1135091             0
# 151              latestEraOrHighestErathem      1135091             0
# 152           earliestPeriodOrLowestSystem      1135091             0
# 153            latestPeriodOrHighestSystem      1135091             0
# 154            earliestEpochOrLowestSeries      1135091             0
# 155             latestEpochOrHighestSeries      1135091             0
# 156               earliestAgeOrLowestStage      1135091             0
# 157                latestAgeOrHighestStage      1135091             0
# 158             lowestBiostratigraphicZone      1135091             0
# 159            highestBiostratigraphicZone      1135091             0
# 160                lithostratigraphicTerms      1135091             0
# 161                                  group      1135091             0
# 162                              formation      1135091             0
# 163                                 member      1135091             0
# 164                                    bed      1135091             0
# 165                       identificationID      1135091          2945
# 166                identificationQualifier      1135091             0
# 167                             typeStatus      1135091             0
# 168                           identifiedBy      1135091             0
# 169                         dateIdentified      1135091          2945
# 170               identificationReferences      1135091             0
# 171       identificationVerificationStatus      1135091             0
# 172                  identificationRemarks      1135091             2
# 173                                taxonID      1135091          2991
# 174                       scientificNameID      1135091             0
# 175                    acceptedNameUsageID      1135091       1135091
# 176                      parentNameUsageID      1135091             0
# 177                    originalNameUsageID      1135091             0
# 178                      nameAccordingToID      1135091             0
# 179                      namePublishedInID      1135091             0
# 180                         taxonConceptID      1135091             0
# 181                         scientificName      1135091       1135091
# 182                      acceptedNameUsage      1135091             0
# 183                        parentNameUsage      1135091             0
# 184                      originalNameUsage      1135091             0
# 185                        nameAccordingTo      1135091             0
# 186                        namePublishedIn      1135091             0
# 187                    namePublishedInYear      1135091             0
# 188                   higherClassification      1135091            12
# 189                                kingdom      1135091       1135091
# 190                                 phylum      1135091       1135091
# 191                                  class      1135091       1135091
# 192                                  order      1135091       1135091
# 193                                 family      1135091       1135091
# 194                                  genus      1135091       1135091
# 195                               subgenus      1135091             0
# 196                        specificEpithet      1135091       1135091
# 197                   infraspecificEpithet      1135091             0
# 198                              taxonRank      1135091       1135091
# 199                      verbatimTaxonRank      1135091             0
# 200                         vernacularName      1135091            12
# 201                      nomenclaturalCode      1135091            12
# 202                        taxonomicStatus      1135091       1135091
# 203                    nomenclaturalStatus      1135091             0
# 204                           taxonRemarks      1135091             0
# 205                             datasetKey      1135091       1135091
# 206                      publishingCountry      1135091       1135091
# 207                        lastInterpreted      1135091       1135091
# 208                              elevation      1135091             0
# 209                      elevationAccuracy      1135091             0
# 210                                  depth      1135091             0
# 211                          depthAccuracy      1135091             0
# 212                   distanceAboveSurface      1135091             0
# 213           distanceAboveSurfaceAccuracy      1135091             0
# 214                                  issue      1135091        909047
# 215                              mediaType      1135091          2831
# 216                          hasCoordinate      1135091       1135091
# 217                    hasGeospatialIssues      1135091       1135091
# 218                               taxonKey      1135091       1135091
# 219                       acceptedTaxonKey      1135091       1135091
# 220                             kingdomKey      1135091       1135091
# 221                              phylumKey      1135091       1135091
# 222                               classKey      1135091       1135091
# 223                               orderKey      1135091       1135091
# 224                              familyKey      1135091       1135091
# 225                               genusKey      1135091       1135091
# 226                            subgenusKey      1135091             0
# 227                             speciesKey      1135091       1135091
# 228                                species      1135091       1135091
# 229                            genericName      1135091       1135091
# 230                 acceptedScientificName      1135091       1135091
# 231                 verbatimScientificName      1135091             0
# 232                           typifiedName      1135091       1135091
# 233                               protocol      1135091       1135091
# 234                             lastParsed      1135091       1135091
# 235                            lastCrawled      1135091       1135091
# 236                            repatriated      1135091             0
# 237               relativeOrganismQuantity      1135091             0

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:40:19.101090
