# %% [markdown]
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### Set Variables - fill out stuff in this cell.
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
species_id = 'bdowox0'
summary_name = 'Downer'
gbif_req_id = 'Gr24'
gbif_filter_id = 'test1'
default_coordUncertainty = 1000       # Note above.
workDir = 'T:/temp/'   # Be sure to create folders named "Inputs" and "Outputs" here.
codeDir = 'T:/code/wildlife-wrangler/'
paramdb = 'P:/Proj3/USGap/Vert/DBase/wildlife-wrangler.sqlite'
configDir = 'T:/GAP/Data/'  # Path to folder where saved your wildlifeconfig file.

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temp fix, hopefully.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410

# %%
import os
os.environ['PROJ_LIB'] = r'c:\Users\nmtarr\AppData\Local\Continuum\miniconda3\envs\wrangler\Library\share'

# %% [markdown]
# ### Setup - nothing to fill out in this cell

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
sys.path.append(codeDir)
import wrangler_functions as functions
outDir = workDir
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
# Out:
# Notebook run 2020-04-09 10:16:50.491765
# T:/temp/bdowox0Gr24test1.sqlite

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
sp_dict = dict(zip(cols, vals))
sp_df = pd.DataFrame.from_dict(sp_dict, orient='index', columns=['VALUE'])
sp_df.index.name = 'ATTRIBUTE'
print("SPECIES CONCEPT RECORD")
print(sp_df)
# Out:
# SPECIES CONCEPT RECORD
#                                         VALUE
# ATTRIBUTE
# species_id                            bdowox0
# fws_id                                   None
# gap_id                                 bdowox
# itis_tsn                               178259
# gbif_id                               2477781
# bcb_id                                   None
# ebird_id                                 None
# common_name                  downy woodpecker
# scientific_name            Picoides pubescens
# start_year                               None
# split_from                               None
# end_year                                 2018
# lumped_into                           bdowox1
# geometry                                 None
# detection_distance_meters                 200
# vetted_how                 Consulted avibase.
# vetted_who                            N. Tarr
# vetted_date                         3/10/2020
# notes                                    None

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
request_df = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(request_df.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                               Gr24
# source                                   GBIF
# lat_range                                None
# lon_range                                None
# years_range                         1999,2020
# months_range                             1,12
# geoissue                                False
# coordinate                               True
# country                                    US
# geometry                                 None
# creator                               N. Tarr
# notes           Used for tests of large do...
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
filter_df = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(filter_df.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                   test1
# dataset                                      GBIF
# institutions_omit                             MCZ
# collection_codes_omit                        None
# datasets_omit                                None
# has_coordinate_uncertainty                      0
# max_coordinate_uncertainty                  10000
# bases_omit                    MACHINE_OBSERVATION
# sampling_protocols_omit                      None
# issues_omit                                  None
# duplicates_OK                               False
# creator                                      None
# notes                                        None
# Name: 0, dtype: object

# %% [markdown]
# ## Filter set justification
#
# **default_coord_uncertainty:** Set to 1000m to be a little cautious.  May overide values before applying to range update, assessing based on age and source.
#
# **years_range:** The range update objective is to represent "historic" data.  Start year picked based on roughly when modern GPS became accessible.  End year chosen not to overlap with the query for recent records (GBIFr25).
#
# **months_range:** There is no reason to limit on month for this species.
#
# **geoissue:** Due to the spatial aspects of the intended application, persistent geoissues would be problematic.
#
# **coordinate:** Coordinates are required for the spatial nature of the intended applications (range map updates).
#
# **country:** GAP ranges only cover the lower 48 states.
#
# **geometry:** No extra geometry filters deployed as there is not basis or reason to do so.
#
# **collection_codes_omit:** No basis or reason to omit based on collection.  Weighting records may be adjusted based on collection later though.
#
# **institutions_omit:** No basis or reason to omit based on collection.  Weighting records may be adjusted based on collection later though.
#
# **datasets_omit:** No basis or reason to omit based on collection.  Weighting records may be adjusted based on collection later though.
#
# **has_coordinate_uncertainty:** Lack of coordinate uncertainty will/can be handled with default values for this application.
#
# **max_coordinate_uncertainty:** Records with large coordinate uncertainty values effectively get dropped when assessed against the locations of 12 digit hucs and counties.
#
# **bases_omit:** Fossils are not appropriate for GAP range maps.
#
# **sampling_protocols_omit:** No basis or reason to omit based on collection.  Weighting records may be adjusted based on collection later though.
#
# **issues_omit:** 'TAXON_MATCH_HIGHERRANK' -- Records must match species concept of the GAP data; 'RECORDED_DATE_MISMATCH' -- OK to use since temporal extent is so long; 'GEODETIC_DATUM_INVALID' -- Omit because could cause wrong huc to be selected; 'COORDINATE_UNCERTAINTY_METERS_INVALID' -- Kept because value can be overriden later; 'TYPE_STATUS_INVALID' -- Not sure what that means but sounds bad.
#
# **duplicates:** The quality of duplicates on date and x,y location is questionable, so erring on the side of caution.

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                   password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.448234
# Got request params and sorted out geometry constraints: 0:00:00.002993
# 255008 records available
# Your download key is  0037940-200221144449610
# Downloading Darwin Core Archive zip file for this species .....
# Download file size: 39299531 bytes
# On disk at T:/temp//0037940-200221144449610.zip
# Download complete: 0:12:10.286330
# Downloaded and loaded records: 0:00:12.599979
# Summarized fields returned: 0:00:01.132504
# Created summary table of request results: 0:00:00.244771
# Performed post-request filtering: 0:00:00.509833
# Calculated new columns, deleted some too: 0:00:00.443120
# 78121 duplicate records dropped: 1:01:49.370046
# Inserted records into table: 0:00:04.874113
# Summarized unique values retained: 0:00:00.075885
# Updated occurrences table geometry column: 0:00:51.164407
# Buffered points: 0:01:53.744391
# Exported shapefile: 0:00:28.653481
#
# Records saved in T:/temp/bdowox0Gr24test1.sqlite

# %% [markdown]
# ### Connect to output database, record species and filter info.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
sp_df.to_sql(name='species_concept', con=conn_occ, if_exists='replace')
request_df.to_sql(name=gbif_req_id, con=conn_occ, if_exists='replace')
filter_df.to_sql(name=gbif_filter_id, con=conn_occ, if_exists='replace')

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 176790 records

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#                   institutionCode                 collectionCode                    datasetName       0
# 0                            AMNH                          Birds           AMNH Bird Collection      31
# 1                     Anymals.org                     user: 1475  Anymals+plants - Citizen S...       1
# 2                     Anymals.org                     user: 5465  Anymals+plants - Citizen S...       1
# 3                     Anymals.org                     user: 6025  Anymals+plants - Citizen S...       1
# 4                     Anymals.org                     user: 7136  Anymals+plants - Citizen S...       1
# 5                            BGBM                           BoBO  BoBO - Botanic Garden and ...       1
# 6   BSC; Bird Studies Canada -...  MMP; Marsh Monitoring Prog...  Marsh Monitoring Program -...      37
# 7   Borror Laboratory of Bioac...                     Recordings  Borror Lab of Bioacoustics...      47
# 8                             CAS                            ORN          CAS Ornithology (ORN)       4
# 9                            CHAS                 Bird specimens      CHAS Ornithology (Arctos)       1
# 10                            CLO                           GBBC      Great Backyard Bird Count  252954
# 11                            CLO                             ML  Macaulay Library Audio and...      59
# 12                           CMNH                          Birds          CMNH Birds Collection       3
# 13                           CUMV                           Bird           CUMV Bird Collection      27
# 14                           DMNH                           Bird                     DMNH Birds       5
# 15                           DMNS                 Bird specimens  DMNS Bird Collection (Arctos)      38
# 16                            ISU                          Birds                      ISU Birds       8
# 17                             KU                          Birds    KUBI Ornithology Collection      14
# 18                           LACM                          Birds     LACM Vertebrate Collection       1
# 19                            MCZ                            Orn  Museum of Comparative Zool...       9
# 20                           MMNH                           Bird              Bell Museum birds      10
# 21                            MSB                 Bird specimens   MSB Bird Collection (Arctos)      23
# 22                           NYSM                             ZO                     NYSM Birds       1
# 23                           OMNH                          Birds                Birds Specimens       2
# 24                           OMNH                           OCGR              Tissues Specimens       5
# 25  Ohio State University - Bi...                          Birds  Ohio State University Tetr...       1
# 26                           PRBO                        PRBO-PC  Point Reyes Bird Observato...    1371
# 27                            PSM                           Bird     PSM Vertebrates Collection       6
# 28                            RSL                             PC  U.S.D.A. Forest Service, R...     265
# 29                          SBMNH                             AV       SBMNH Vertebrate Zoology       3
# 30                          SDNHM                          Birds         SDNHM Birds Collection       1
# 31                           TCWC                          Birds  Biodiversity Research and ...       5
# 32                            UAM                 Bird specimens   UAM Bird Collection (Arctos)      21
# 33                           UMMZ                          birds  University of Michigan Mus...      17
# 34                           USNM                          Birds   NMNH Extant Specimen Records       2
# 35                           UWBM                           Bird    UWBM Ornithology Collection      22
# 36                           WFVZ                           Bird          WFVZ Bird Collections       1

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#                   institutionCode                 collectionCode                    datasetName  COUNT(occ_id)
# 0                            None                           None                      Bioimages              1
# 1                            None                           None  Geographically tagged INSD...              4
# 2                            None                           None         Questagame weekly feed              3
# 3                            AMNH                          Birds           AMNH Bird Collection             11
# 4                     Anymals.org                     user: 1475  Anymals+plants - Citizen S...              1
# 5                     Anymals.org                     user: 5465  Anymals+plants - Citizen S...              1
# 6                     Anymals.org                     user: 6025  Anymals+plants - Citizen S...              1
# 7                     Anymals.org                     user: 7136  Anymals+plants - Citizen S...              1
# 8                            BGBM                           BoBO  BoBO - Botanic Garden and ...              1
# 9   BSC; Bird Studies Canada -...  MMP; Marsh Monitoring Prog...  Marsh Monitoring Program -...             33
# 10  Borror Laboratory of Bioac...                     Recordings  Borror Lab of Bioacoustics...             25
# 11                            CAS                            ORN          CAS Ornithology (ORN)              4
# 12                           CHAS                 Bird specimens      CHAS Ornithology (Arctos)              1
# 13                            CLO                           GBBC      Great Backyard Bird Count         175103
# 14                           CMNH                          Birds          CMNH Birds Collection              3
# 15                           CUMV                           Bird           CUMV Bird Collection             26
# 16                           DMNH                           Bird                     DMNH Birds              5
# 17                           DMNS                 Bird specimens  DMNS Bird Collection (Arctos)             37
# 18                            ISU                          Birds                      ISU Birds              8
# 19                             KU                          Birds    KUBI Ornithology Collection             12
# 20                           LACM                          Birds     LACM Vertebrate Collection              1
# 21                           MMNH                           Bird              Bell Museum birds              7
# 22                            MSB                 Bird specimens   MSB Bird Collection (Arctos)             19
# 23                           NYSM                             ZO                     NYSM Birds              1
# 24                           OMNH                          Birds                Birds Specimens              1
# 25                           OMNH                           OCGR              Tissues Specimens              4
# 26  Ohio State University - Bi...                          Birds  Ohio State University Tetr...              1
# 27                           PRBO                        PRBO-PC  Point Reyes Bird Observato...           1198
# 28                            PSM                           Bird     PSM Vertebrates Collection              4
# 29                            RSL                             PC  U.S.D.A. Forest Service, R...            227
# 30                          SBMNH                             AV       SBMNH Vertebrate Zoology              3
# 31                          SDNHM                          Birds         SDNHM Birds Collection              1
# 32                           TCWC                          Birds  Biodiversity Research and ...              4
# 33                           UMMZ                          birds  University of Michigan Mus...             17
# 34                           USNM                          Birds   NMNH Extant Specimen Records              2
# 35                           UWBM                           Bird    UWBM Ornithology Collection             18
# 36                           WFVZ                           Bird          WFVZ Bird Collections              1

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#          basisOfRecord   count
# 0    HUMAN_OBSERVATION      56
# 1  MACHINE_OBSERVATION      59
# 2          OBSERVATION  254627
# 3   PRESERVED_SPECIMEN     266

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#         basisOfRecord   count
# 0   HUMAN_OBSERVATION      34
# 1         OBSERVATION  176561
# 2  PRESERVED_SPECIMEN     195

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
#           samplingProtocol  count
# 0                     Shot      2
# 1                  Shotgun     19
# 2              Window Kill      1
# 3           none specified     48
# 4                  salvage     19
# 5       salvage-cat caught      2
# 6    salvage-window strike      8
# 7                 salvaged      8
# 8   salvaged - window kill      1
# 9                     shot     12
# 10             window kill      1
# 11           window strike      1

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#          samplingProtocol   count
# 0                    None  176712
# 1                    Shot       1
# 2                 Shotgun       7
# 3             Window Kill       1
# 4          none specified      26
# 5                 salvage      18
# 6      salvage-cat caught       2
# 7   salvage-window strike       8
# 8                salvaged       2
# 9                    shot      11
# 10            window kill       1
# 11          window strike       1

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                     issues   count
# 0                                                   COORDINATE_REPROJECTED       1
# 1                                                       COORDINATE_ROUNDED     109
# 2                      COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDINATES       1
# 3                          COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84   24313
# 4   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       3
# 5                            COORDINATE_ROUNDED;PRESUMED_NEGATED_LONGITUDE       1
# 6                                         COUNTRY_DERIVED_FROM_COORDINATES       3
# 7            COUNTRY_DERIVED_FROM_COORDINATES;GEODETIC_DATUM_ASSUMED_WGS84       5
# 8                                             GEODETIC_DATUM_ASSUMED_WGS84  230122
# 9                GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_PRECISION_INVALID     265
# 10                     GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       2
# 11                               RECORDED_DATE_MISMATCH;COORDINATE_ROUNDED       1
# 12                                                  TAXON_MATCH_HIGHERRANK       9

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                                                     issues   count
# 0                                                                               97
# 1                                                   COORDINATE_REPROJECTED       1
# 2                                                       COORDINATE_ROUNDED      70
# 3                      COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDINATES       1
# 4                          COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84   15105
# 5   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       3
# 6                                         COUNTRY_DERIVED_FROM_COORDINATES       3
# 7            COUNTRY_DERIVED_FROM_COORDINATES;GEODETIC_DATUM_ASSUMED_WGS84       4
# 8                                             GEODETIC_DATUM_ASSUMED_WGS84  161277
# 9                GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_PRECISION_INVALID     227
# 10                     GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       1
# 11                               RECORDED_DATE_MISMATCH;COORDINATE_ROUNDED       1

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
try:
    functions.MapShapefilePolygons(map_these=map_these, title=title)
except Exception as e:
    print("Unable to map:  " + str(e))
# Out:
# T:/code/wildlife-wrangler\wrangler_functions.py:41: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   height=3200000, width=5000000)
# T:/code/wildlife-wrangler\wrangler_functions.py:43: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawstates(color='grey')
# T:/code/wildlife-wrangler\wrangler_functions.py:44: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawcountries(color='grey')
# T:/code/wildlife-wrangler\wrangler_functions.py:55: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   color=mapfile['linecolor'])

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty - Zoomed In")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty - Zoomed In')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# MANAGED, NATIVE, nan

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# A, nan

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                  attribute  included(n)  populated(n)
# Field
# 0                                 abstract       255008             0
# 1                             accessRights       255008           238
# 2                            accrualMethod       255008             0
# 3                       accrualPeriodicity       255008             0
# 4                            accrualPolicy       255008             0
# 5                              alternative       255008             0
# 6                                 audience       255008             0
# 7                                available       255008             0
# 8                    bibliographicCitation       255008            37
# 9                               conformsTo       255008             0
# 10                             contributor       255008             0
# 11                                coverage       255008             0
# 12                                 created       255008             5
# 13                                 creator       255008             0
# 14                                    date       255008             0
# 15                            dateAccepted       255008             0
# 16                         dateCopyrighted       255008             0
# 17                           dateSubmitted       255008             0
# 18                             description       255008             0
# 19                          educationLevel       255008             0
# 20                                  extent       255008             0
# 21                                  format       255008             0
# 22                               hasFormat       255008             0
# 23                                 hasPart       255008             0
# 24                              hasVersion       255008             0
# 25                              identifier       255008        254996
# 26                     instructionalMethod       255008             0
# 27                              isFormatOf       255008             0
# 28                                isPartOf       255008             0
# 29                          isReferencedBy       255008             0
# 30                            isReplacedBy       255008             0
# 31                            isRequiredBy       255008             0
# 32                             isVersionOf       255008             0
# 33                                  issued       255008             0
# 34                                language       255008           324
# 35                                 license       255008        255008
# 36                                mediator       255008             0
# 37                                  medium       255008             0
# 38                                modified       255008           364
# 39                              provenance       255008             0
# 40                               publisher       255008        255008
# 41                              references       255008           256
# 42                                relation       255008             0
# 43                                replaces       255008             0
# 44                                requires       255008             0
# 45                                  rights       255008            69
# 46                            rightsHolder       255008            19
# 47                                  source       255008             0
# 48                                 spatial       255008             0
# 49                                 subject       255008             0
# 50                         tableOfContents       255008             0
# 51                                temporal       255008             0
# 52                                   title       255008             0
# 53                                    type       255008           277
# 54                                   valid       255008             0
# 55                           institutionID       255008           273
# 56                            collectionID       255008           198
# 57                               datasetID       255008             0
# 58                         institutionCode       255008        254999
# 59                          collectionCode       255008        254999
# 60                             datasetName       255008        255008
# 61                    ownerInstitutionCode       255008             9
# 62                           basisOfRecord       255008        255008
# 63                     informationWithheld       255008            22
# 64                     dataGeneralizations       255008             3
# 65                       dynamicProperties       255008           159
# 66                            occurrenceID       255008           338
# 67                           catalogNumber       255008        254999
# 68                            recordNumber       255008            64
# 69                              recordedBy       255008           387
# 70                         individualCount       255008           194
# 71                        organismQuantity       255008             0
# 72                    organismQuantityType       255008             0
# 73                                     sex       255008           248
# 74                               lifeStage       255008            98
# 75                   reproductiveCondition       255008            24
# 76                                behavior       255008            59
# 77                      establishmentMeans       255008           181
# 78                        occurrenceStatus       255008           182
# 79                            preparations       255008           252
# 80                             disposition       255008            30
# 81                    associatedReferences       255008             0
# 82                     associatedSequences       255008             5
# 83                          associatedTaxa       255008            34
# 84                     otherCatalogNumbers       255008           123
# 85                       occurrenceRemarks       255008           160
# 86                              organismID       255008            84
# 87                            organismName       255008             0
# 88                           organismScope       255008             0
# 89                   associatedOccurrences       255008             2
# 90                     associatedOrganisms       255008             0
# 91                 previousIdentifications       255008            84
# 92                         organismRemarks       255008             2
# 93                        materialSampleID       255008             0
# 94                                 eventID       255008             0
# 95                           parentEventID       255008             0
# 96                             fieldNumber       255008            43
# 97                               eventDate       255008        255008
# 98                               eventTime       255008             1
# 99                          startDayOfYear       255008           182
# 100                           endDayOfYear       255008           245
# 101                                   year       255008        255008
# 102                                  month       255008        255008
# 103                                    day       255008        254990
# 104                      verbatimEventDate       255008           299
# 105                                habitat       255008            25
# 106                       samplingProtocol       255008           122
# 107                         samplingEffort       255008             0
# 108                        sampleSizeValue       255008             0
# 109                         sampleSizeUnit       255008             0
# 110                             fieldNotes       255008            48
# 111                           eventRemarks       255008            18
# 112                             locationID       255008             0
# 113                      higherGeographyID       255008             0
# 114                        higherGeography       255008           302
# 115                              continent       255008           575
# 116                              waterBody       255008             6
# 117                            islandGroup       255008             9
# 118                                 island       255008             4
# 119                            countryCode       255008        255008
# 120                          stateProvince       255008        254994
# 121                                 county       255008        254819
# 122                           municipality       255008             0
# 123                               locality       255008        254696
# 124                       verbatimLocality       255008           271
# 125                      verbatimElevation       255008            39
# 126                          verbatimDepth       255008             0
# 127    minimumDistanceAboveSurfaceInMeters       255008             0
# 128    maximumDistanceAboveSurfaceInMeters       255008             0
# 129                    locationAccordingTo       255008            83
# 130                        locationRemarks       255008             3
# 131                        decimalLatitude       255008        255008
# 132                       decimalLongitude       255008        255008
# 133          coordinateUncertaintyInMeters       255008           203
# 134                    coordinatePrecision       255008             0
# 135                  pointRadiusSpatialFit       255008             0
# 136               verbatimCoordinateSystem       255008           100
# 137                            verbatimSRS       255008             0
# 138                           footprintWKT       255008             0
# 139                           footprintSRS       255008             0
# 140                    footprintSpatialFit       255008             0
# 141                        georeferencedBy       255008           122
# 142                      georeferencedDate       255008           130
# 143                   georeferenceProtocol       255008           163
# 144                    georeferenceSources       255008           224
# 145         georeferenceVerificationStatus       255008           291
# 146                    georeferenceRemarks       255008            68
# 147                    geologicalContextID       255008             0
# 148            earliestEonOrLowestEonothem       255008             0
# 149             latestEonOrHighestEonothem       255008             0
# 150             earliestEraOrLowestErathem       255008             0
# 151              latestEraOrHighestErathem       255008             0
# 152           earliestPeriodOrLowestSystem       255008             0
# 153            latestPeriodOrHighestSystem       255008             0
# 154            earliestEpochOrLowestSeries       255008             0
# 155             latestEpochOrHighestSeries       255008             0
# 156               earliestAgeOrLowestStage       255008             0
# 157                latestAgeOrHighestStage       255008             0
# 158             lowestBiostratigraphicZone       255008             0
# 159            highestBiostratigraphicZone       255008             0
# 160                lithostratigraphicTerms       255008             0
# 161                                  group       255008             0
# 162                              formation       255008             0
# 163                                 member       255008             0
# 164                                    bed       255008             0
# 165                       identificationID       255008             0
# 166                identificationQualifier       255008            83
# 167                             typeStatus       255008             0
# 168                           identifiedBy       255008           102
# 169                         dateIdentified       255008           126
# 170               identificationReferences       255008             1
# 171       identificationVerificationStatus       255008            83
# 172                  identificationRemarks       255008            86
# 173                                taxonID       255008            15
# 174                       scientificNameID       255008            48
# 175                    acceptedNameUsageID       255008        255008
# 176                      parentNameUsageID       255008             0
# 177                    originalNameUsageID       255008             0
# 178                      nameAccordingToID       255008             0
# 179                      namePublishedInID       255008             0
# 180                         taxonConceptID       255008             0
# 181                         scientificName       255008        255008
# 182                      acceptedNameUsage       255008             0
# 183                        parentNameUsage       255008             0
# 184                      originalNameUsage       255008             0
# 185                        nameAccordingTo       255008             0
# 186                        namePublishedIn       255008             0
# 187                    namePublishedInYear       255008             0
# 188                   higherClassification       255008           248
# 189                                kingdom       255008        255008
# 190                                 phylum       255008        255008
# 191                                  class       255008        255008
# 192                                  order       255008        255008
# 193                                 family       255008        255008
# 194                                  genus       255008        255008
# 195                               subgenus       255008             0
# 196                        specificEpithet       255008        255008
# 197                   infraspecificEpithet       255008             0
# 198                              taxonRank       255008        255008
# 199                      verbatimTaxonRank       255008             0
# 200                         vernacularName       255008            88
# 201                      nomenclaturalCode       255008           271
# 202                        taxonomicStatus       255008        255008
# 203                    nomenclaturalStatus       255008             0
# 204                           taxonRemarks       255008             0
# 205                             datasetKey       255008        255008
# 206                      publishingCountry       255008        255008
# 207                        lastInterpreted       255008        255008
# 208                              elevation       255008           354
# 209                      elevationAccuracy       255008           323
# 210                                  depth       255008             0
# 211                          depthAccuracy       255008             0
# 212                   distanceAboveSurface       255008             0
# 213           distanceAboveSurfaceAccuracy       255008             0
# 214                                  issue       255008        254835
# 215                              mediaType       255008            51
# 216                          hasCoordinate       255008        255008
# 217                    hasGeospatialIssues       255008        255008
# 218                               taxonKey       255008        255008
# 219                       acceptedTaxonKey       255008        255008
# 220                             kingdomKey       255008        255008
# 221                              phylumKey       255008        255008
# 222                               classKey       255008        255008
# 223                               orderKey       255008        255008
# 224                              familyKey       255008        255008
# 225                               genusKey       255008        255008
# 226                            subgenusKey       255008             0
# 227                             speciesKey       255008        255008
# 228                                species       255008        255008
# 229                            genericName       255008        255008
# 230                 acceptedScientificName       255008        255008
# 231                 verbatimScientificName       255008        255008
# 232                           typifiedName       255008             0
# 233                               protocol       255008        255008
# 234                             lastParsed       255008        255008
# 235                            lastCrawled       255008        255008
# 236                            repatriated       255008        255008
# 237               relativeOrganismQuantity       255008             0
# 238                           recordedByID       255008             0
# 239                         identifiedByID       255008             0

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 1:18:58.386848
