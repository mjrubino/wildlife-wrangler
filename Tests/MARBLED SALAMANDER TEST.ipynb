# %% [markdown]
# # Marbled Salamander Test
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### Set Variables - fill out stuff in this cell.
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
species_id = 'amasax0'
summary_name = 'Marbles'
gbif_req_id = 'GBIFr24'
gbif_filter_id = 'GBIFf9'
default_coordUncertainty = 1000       # Note above.
workDir = 'T:/temp/'   # Be sure to create folders named "Inputs" and "Outputs" here.
codeDir = 'T:/code/wildlife-wrangler/'
paramdb = 'P:/Proj3/USGap/Vert/DBase/wildlife-wrangler.sqlite'
configDir = 'T:/GAP/Data/'  # Path to folder where saved your wildlifeconfig file.

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temp fix, hopefully.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410

# %%
import os
os.environ['PROJ_LIB'] = r'c:\Users\nmtarr\AppData\Local\Continuum\miniconda3\envs\wrangler\Library\share'

# %% [markdown]
# ### Setup - nothing to fill out here

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
sys.path.append(codeDir)
import repo_functions as functions
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
# Out:
# Notebook run 2020-03-18 13:38:25.809027
# T:/temp/Outputs/amasax0GBIFr24GBIFf9.sqlite

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
sp_dict = dict(zip(cols, vals))
sp_df = pd.DataFrame.from_dict(sp_dict, orient='index', columns=['VALUE'])
sp_df.index.name = 'ATTRIBUTE'
print(sp_df)
# Out:
#                                                    VALUE
# ATTRIBUTE
# species_id                                       amasax0
# fws_id                                              None
# gap_id                                            amasax
# itis_tsn                                          173591
# gbif_id                                          2431951
# bcb_id                                              None
# ebird_id                                            None
# common_name                           marbled salamander
# scientific_name                         Ambystoma opacum
# start_year
# split_from                                          None
# end_year                                            None
# lumped_into                                         None
# geometry                                            None
# detection_distance_meters                              0
# vetted_how                 Consulted ITIS and NatureS...
# vetted_who                                       N. Tarr
# vetted_date                                    3/10/2020
# notes                                               None

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
request_df = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(request_df.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                            GBIFr24
# source                                   GBIF
# lat_range                                None
# lon_range                                None
# years_range                         1999,2020
# months_range                             1,12
# geoissue                                False
# coordinate                               True
# country                                    US
# geometry                                 None
# creator                               N. Tarr
# notes           Used for tests of large do...
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
filter_df = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(filter_df.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                            GBIFf9
# dataset                                                GBIF
# institutions_omit                                      None
# collection_codes_omit                                  None
# datasets_omit                                          None
# has_coordinate_uncertainty                                0
# max_coordinate_uncertainty                            10000
# bases_omit                                             None
# sampling_protocols_omit                                None
# issues_omit                                            None
# duplicates_OK                                          True
# creator                                             N. Tarr
# notes                         Used for speed tests.  Let...
# Name: 0, dtype: object

# %% [markdown]
# ## Filter set justification
# Enter your justification for the following settings.
#
# **default_coord_uncertainty:**
#
# **years_range:**
#
# **months_range:**
#
# **geoissue:**
#
# **coordinate:**
#
# **country:**
#
# **geometry:**
#
# **collection_codes_omit:**
#
# **institutions_omit:**
#
# **datasets_omit:**
#
# **has_coordinate_uncertainty:**
#
# **max_coordinate_uncertainty:**
#
# **bases_omit:**
#
# **sampling_protocols_omit:**
#
# **issues_omit:**
#
# **duplicates:**

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, inDir, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                   password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.269479
# Got request params and sorted out geometry constraints: 0:00:00.002997
# 3768 records available
# Downloaded records: 0:00:21.179609
# Summarized fields returned: 0:01:46.801693
# Created summary table of request results: 0:00:00.039951
# Performed post-request filtering: 0:00:00.012950
# Calculated new columns, deleted some too: 0:00:00.020911
# Inserted records into table: 0:00:00.141564
# Summarized unique values retained: 0:00:00.003985
# Updated occurrences table geometry column: 0:00:00.883364
# DUPLICATES ON LATITUDE, LONGITUDE, DATE-TIME INCLUDED
# Buffered points: 0:00:02.312203
# Exported maps: 0:00:00.745396
#
# Records saved in T:/temp/Outputs/amasax0GBIFr24GBIFf9.sqlite

# %% [markdown]
# ### Connect to output database, record species and filter info.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
sp_df.to_sql(name='species_concept', con=conn_occ, if_exists='replace')  
request_df.T.to_sql(name=gbif_req_id, con=conn_occ, if_exists='replace')  
filter_df.T.to_sql(name=gbif_filter_id, con=conn_occ, if_exists='replace')

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 3156 records

# %% [markdown]
# ### Are there duplicate records left?
# NOTE:  DUPLICATE HANDLING MAY NOT BE PERFORMING CORRECTLY.
# Duplicates based on latitude, longitude, and date-time should have been removed, with the record with the highest individualCount retained.

# %%
dups0 = curs_occ.execute("""SELECT count(occ_id) FROM occurrences WHERE occ_id NOT IN (SELECT occ_id FROM occurrences GROUP BY latitude, longitude, occurrenceDate HAVING max(IndividualCount));""").fetchall()
print(str(dups0[0][0]) + ' duplicate records retained based on xy coordinate and date-time')
# Out:
# 2570 duplicate records retained based on xy coordinate and date-time

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode         collectionCode                    datasetName     0
# 0              AUM                  Herps                        UNKNOWN    13
# 1               CM                  Herps                        UNKNOWN     1
# 2             CUMV                  Herps                        UNKNOWN   160
# 3             FHSM                   HERP                        UNKNOWN     6
# 4              GSU               GSU-Herp  Georgia Southern Universit...     6
# 5            LSUMZ                  Herps                        UNKNOWN     1
# 6              MCZ                   Herp                        UNKNOWN   187
# 7              MCZ                HerpOBS                        UNKNOWN     1
# 8              MPM                      H                        UNKNOWN     8
# 9             NCSM                   Herp    NCSM Herpetology Collection    59
# 10            NEON              HEVC-GBTS                        UNKNOWN     1
# 11            OMNH             Amphibians                        UNKNOWN   100
# 12            OMNH                   OCGR  Oklahoma Collection of Gen...    73
# 13            TCWC            Herpetology                        UNKNOWN    11
# 14              UF                   Herp                        UNKNOWN     4
# 15         UNKNOWN                UNKNOWN                        UNKNOWN     4
# 16            USNM  Amphibians & Reptiles            NMNH Extant Biology    10
# 17             YPM                     VZ                        UNKNOWN   534
# 18     iNaturalist           Observations  iNaturalist research-grade...  2589

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode         collectionCode                    datasetName  COUNT(occ_id)
# 0              AUM                  Herps                        UNKNOWN              9
# 1               CM                  Herps                        UNKNOWN              1
# 2             CUMV                  Herps                        UNKNOWN            153
# 3             FHSM                   HERP                        UNKNOWN              6
# 4              GSU               GSU-Herp  Georgia Southern Universit...              2
# 5            LSUMZ                  Herps                        UNKNOWN              1
# 6              MCZ                   Herp                        UNKNOWN            187
# 7              MCZ                HerpOBS                        UNKNOWN              1
# 8              MPM                      H                        UNKNOWN              8
# 9             NCSM                   Herp    NCSM Herpetology Collection             51
# 10            NEON              HEVC-GBTS                        UNKNOWN              1
# 11            OMNH             Amphibians                        UNKNOWN             97
# 12            OMNH                   OCGR  Oklahoma Collection of Gen...             71
# 13            TCWC            Herpetology                        UNKNOWN              8
# 14              UF                   Herp                        UNKNOWN              4
# 15         UNKNOWN                UNKNOWN                        UNKNOWN              3
# 16            USNM  Amphibians & Reptiles            NMNH Extant Biology             10
# 17             YPM                     VZ                        UNKNOWN            436
# 18     iNaturalist           Observations  iNaturalist research-grade...           2107

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#          basisOfRecord  count
# 0    HUMAN_OBSERVATION   2592
# 1  MACHINE_OBSERVATION      1
# 2   PRESERVED_SPECIMEN   1175

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#          basisOfRecord  count
# 0    HUMAN_OBSERVATION   2109
# 1  MACHINE_OBSERVATION      1
# 2   PRESERVED_SPECIMEN   1046

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
#   samplingProtocol  count
# 0          UNKNOWN   3768

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#   samplingProtocol  count
# 0          UNKNOWN   3156

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                              issues  count
# 0                                                        ['COORDINATE_REPROJECTED']      6
# 1        ['COORDINATE_ROUNDED', 'COORDINATE_REPROJECTED', 'TAXON_MATCH_HIGHERRANK']     38
# 2                                  ['COORDINATE_ROUNDED', 'COORDINATE_REPROJECTED']    168
# 3   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84', 'COORDINATE_UNCERTAIN...      2
# 4                            ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84']   2269
# 5   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS...     50
# 6   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS...    111
# 7                              ['COORDINATE_ROUNDED', 'PRESUMED_NEGATED_LONGITUDE']      1
# 8                                  ['COORDINATE_ROUNDED', 'TAXON_MATCH_HIGHERRANK']     12
# 9                                                            ['COORDINATE_ROUNDED']    164
# 10        ['GEODETIC_DATUM_ASSUMED_WGS84', 'COORDINATE_UNCERTAINTY_METERS_INVALID']      1
# 11             ['GEODETIC_DATUM_ASSUMED_WGS84', 'COUNTRY_DERIVED_FROM_COORDINATES']      2
# 12                     ['GEODETIC_DATUM_ASSUMED_WGS84', 'INDIVIDUAL_COUNT_INVALID']      2
# 13                   ['GEODETIC_DATUM_ASSUMED_WGS84', 'PRESUMED_NEGATED_LONGITUDE']      4
# 14                            ['GEODETIC_DATUM_ASSUMED_WGS84', 'TAXON_MATCH_FUZZY']      1
# 15                          ['GEODETIC_DATUM_ASSUMED_WGS84', 'TYPE_STATUS_INVALID']     14
# 16                                                 ['GEODETIC_DATUM_ASSUMED_WGS84']    559
# 17                       ['GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS84']      3
# 18                                                   ['PRESUMED_NEGATED_LONGITUDE']      6
# 19                                                       ['TAXON_MATCH_HIGHERRANK']     11
# 20                                                                               []    344

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                                                              issues  count
# 0                                                        ['COORDINATE_REPROJECTED']      6
# 1        ['COORDINATE_ROUNDED', 'COORDINATE_REPROJECTED', 'TAXON_MATCH_HIGHERRANK']     38
# 2                                  ['COORDINATE_ROUNDED', 'COORDINATE_REPROJECTED']    167
# 3   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84', 'COORDINATE_UNCERTAIN...      2
# 4                            ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84']   1800
# 5   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS...     50
# 6   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS...    111
# 7                              ['COORDINATE_ROUNDED', 'PRESUMED_NEGATED_LONGITUDE']      1
# 8                                  ['COORDINATE_ROUNDED', 'TAXON_MATCH_HIGHERRANK']     12
# 9                                                            ['COORDINATE_ROUNDED']    144
# 10        ['GEODETIC_DATUM_ASSUMED_WGS84', 'COORDINATE_UNCERTAINTY_METERS_INVALID']      1
# 11             ['GEODETIC_DATUM_ASSUMED_WGS84', 'COUNTRY_DERIVED_FROM_COORDINATES']      2
# 12                     ['GEODETIC_DATUM_ASSUMED_WGS84', 'INDIVIDUAL_COUNT_INVALID']      2
# 13                   ['GEODETIC_DATUM_ASSUMED_WGS84', 'PRESUMED_NEGATED_LONGITUDE']      4
# 14                            ['GEODETIC_DATUM_ASSUMED_WGS84', 'TAXON_MATCH_FUZZY']      1
# 15                          ['GEODETIC_DATUM_ASSUMED_WGS84', 'TYPE_STATUS_INVALID']     14
# 16                                                 ['GEODETIC_DATUM_ASSUMED_WGS84']    507
# 17                       ['GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS84']      3
# 18                                                   ['PRESUMED_NEGATED_LONGITUDE']      4
# 19                                                       ['TAXON_MATCH_HIGHERRANK']      9
# 20                                                                               []    278

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)
# Out:
# T:/code/wildlife-wrangler\repo_functions.py:42: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   height=3200000, width=5000000)
# T:/code/wildlife-wrangler\repo_functions.py:44: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawstates(color='grey')
# T:/code/wildlife-wrangler\repo_functions.py:45: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawcountries(color='grey')
# T:/code/wildlife-wrangler\repo_functions.py:56: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   color=mapfile['linecolor'])

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty - Zoomed In")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty - Zoomed In')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# MANAGED, NATIVE, UNKNOWN

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# UNKNOWN

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                   attribute  included(n)  populated(n)
# Field
# 0                    acceptedScientificName         3768          3768
# 1                          acceptedTaxonKey         3768          3768
# 2                              accessRights          799           799
# 3                     associatedOccurrences            1             1
# 4                      associatedReferences           41            41
# 5                       associatedSequences           64            64
# 6                             basisOfRecord         3768          3768
# 7                                  behavior            4             4
# 8                     bibliographicCitation          777           777
# 9                             catalogNumber         3764          3764
# 10                                    class         3768          3768
# 11                                 classKey         3768          3768
# 12                           collectionCode         3764          3764
# 13                             collectionID          272           272
# 14                                continent         1074          1074
# 15            coordinateUncertaintyInMeters         2544          2544
# 16                                  country         3768          3768
# 17                              countryCode         3768          3768
# 18                                   county         1166          1166
# 19                                  crawlId         3768          3768
# 20                                  created            2             2
# 21                      dataGeneralizations            2             2
# 22                                datasetID           59            59
# 23                               datasetKey         3768          3768
# 24                              datasetName         2737          2737
# 25                           dateIdentified         2583          2583
# 26                                      day         3761          3761
# 27                          decimalLatitude         3768          3768
# 28                         decimalLongitude         3768          3768
# 29                              disposition          247           247
# 30                        dynamicProperties          723           723
# 31                                elevation           13            13
# 32                        elevationAccuracy           12            12
# 33                             endDayOfYear          212           212
# 34                       establishmentMeans          206           206
# 35                                eventDate         3768          3768
# 36                             eventRemarks           16            16
# 37                                eventTime         2342          2342
# 38                               extensions         3768             0
# 39                                    facts         3768             0
# 40                                   family         3768          3768
# 41                                familyKey         3768          3768
# 42                              fieldNumber          730           730
# 43                                   gbifID         3768          3768
# 44                              genericName         3768          3768
# 45                                    genus         3768          3768
# 46                                 genusKey         3768          3768
# 47                            geodeticDatum         3768          3768
# 48                     georeferenceProtocol          706           706
# 49                      georeferenceRemarks          296           296
# 50                      georeferenceSources          780           780
# 51           georeferenceVerificationStatus          467           467
# 52                          georeferencedBy          680           680
# 53                        georeferencedDate          227           227
# 54                                  habitat            4             4
# 55                     higherClassification          940           940
# 56                          higherGeography          942           942
# 57                  http://unknown.org/nick         2589          2589
# 58     http://unknown.org/occurrenceDetails         2589          2589
# 59              http://unknown.org/recordId            1             1
# 60       http://unknown.org/recordedByOrcid           25            25
# 61                         identificationID         2505          2505
# 62                    identificationRemarks           76            76
# 63                             identifiedBy          279           279
# 64                               identifier         3768          3768
# 65                              identifiers         3768             0
# 66                          individualCount          856           856
# 67                      informationWithheld          450           450
# 68                          installationKey         3768          3768
# 69                          institutionCode         3764          3764
# 70                            institutionID          449           449
# 71                                   issues         3768          3424
# 72                                      key         3768          3768
# 73                                  kingdom         3768          3768
# 74                               kingdomKey         3768          3768
# 75                                 language         1073          1073
# 76                              lastCrawled         3768          3768
# 77                          lastInterpreted         3768          3768
# 78                               lastParsed         3768          3768
# 79                                  license         3768          3768
# 80                                lifeStage          324           324
# 81                                 locality         1170          1170
# 82                               locationID           13            13
# 83                          locationRemarks          131           131
# 84                                    media         3768          2429
# 85                                 modified         3670          3670
# 86                                    month         3768          3768
# 87                             municipality          534           534
# 88                        nomenclaturalCode          928           928
# 89                             occurrenceID         3768          3768
# 90                        occurrenceRemarks         1512          1512
# 91                         occurrenceStatus          208           208
# 92                                    order         3768          3768
# 93                                 orderKey         3768          3768
# 94                      otherCatalogNumbers          207           207
# 95                     ownerInstitutionCode          781           781
# 96                                   phylum         3768          3768
# 97                                phylumKey         3768          3768
# 98                             preparations         1084          1084
# 99                  previousIdentifications          534           534
# 100                                protocol         3768          3768
# 101                       publishingCountry         3768          3768
# 102                        publishingOrgKey         3768          3768
# 103                            recordNumber          379           379
# 104                              recordedBy         3697          3697
# 105                              references         3581          3581
# 106                               relations         3768             0
# 107                                  rights         2590          2590
# 108                            rightsHolder         3370          3370
# 109                          scientificName         3768          3768
# 110                                     sex           59            59
# 111                                 species         3768          3768
# 112                              speciesKey         3768          3768
# 113                         specificEpithet         3768          3768
# 114                          startDayOfYear          400           400
# 115                           stateProvince         3764          3764
# 116                                 taxonID         2592          2592
# 117                                taxonKey         3768          3768
# 118                               taxonRank         3768          3768
# 119                            taxonRemarks          534           534
# 120                         taxonomicStatus         3768          3768
# 121                                    type          997           997
# 122                verbatimCoordinateSystem          195           195
# 123                       verbatimElevation          147           147
# 124                       verbatimEventDate         2964          2964
# 125                        verbatimLocality         2974          2974
# 126                             verbatimSRS            4             4
# 127                          vernacularName          666           666
# 128                                    year         3768          3768

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:02:19.140206
