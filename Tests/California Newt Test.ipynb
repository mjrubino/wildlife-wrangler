# %% [markdown]
# # California Newt Test
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### Set Variables - fill out stuff in this cell.
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
species_id = 'acfnex0'
summary_name = 'CalNewt'
gbif_req_id = 'mattTest'
gbif_filter_id = 'mattTest'
default_coordUncertainty = 1000       # Note above.
workDir = 'T:/temp/'   # Be sure to create folders named "Inputs" and "Outputs" here.
codeDir = 'T:/code/wildlife-wrangler/'
paramdb = 'P:/Proj3/USGap/Vert/DBase/wildlife-wrangler.sqlite'
configDir = 'T:/GAP/Data/'

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temp fix, hopefully.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410

# %%
import os
os.environ['PROJ_LIB'] = r'c:\Users\nmtarr\AppData\Local\Continuum\miniconda3\envs\wrangler\Library\share'

# %% [markdown]
# ### Setup - nothing to fill out in this cell

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
sys.path.append(codeDir)
import wrangler_functions as functions
outDir = workDir
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
# Out:
# Notebook run 2020-04-20 14:52:06.111807
# T:/temp/acfnex0mattTestmattTest.sqlite

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
sp_dict = dict(zip(cols, vals))
sp_df = pd.DataFrame.from_dict(sp_dict, orient='index', columns=['VALUE'])
sp_df.index.name = 'ATTRIBUTE'
print("SPECIES CONCEPT RECORD")
print(sp_df)
# Out:
# SPECIES CONCEPT RECORD
#                                      VALUE
# ATTRIBUTE
# species_id                         acfnex0
# fws_id                                None
# gap_id                              aCFNEx
# itis_tsn                            173622
# gbif_id                            2431913
# bcb_id                                None
# ebird_id                              None
# common_name                California Newt
# scientific_name             Taricha torosa
# start_year                            None
# split_from                            None
# end_year                              None
# lumped_into                           None
# geometry                              None
# detection_distance_meters                0
# vetted_how                    NS,GBIF,IUCN
# vetted_who                       M. Rubino
# vetted_date                           None
# notes                                 None

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
request_df = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(request_df.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id       mattTest
# source               GBIF
# lat_range            None
# lon_range            None
# years_range     1999,2020
# months_range         1,12
# geoissue            False
# coordinate           True
# country                US
# geometry             None
# creator         M. Rubino
# notes                None
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
filter_df = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(filter_df.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                            mattTest
# dataset                                  GBIF
# institutions_omit                        None
# collection_codes_omit                    None
# datasets_omit                            None
# has_coordinate_uncertainty                  0
# max_coordinate_uncertainty              10000
# bases_omit                    FOSSIL_SPECIMEN
# sampling_protocols_omit                  None
# issues_omit                              None
# duplicates_OK                           False
# creator                             M. Rubino
# notes                                    None
# Name: 0, dtype: object

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                    password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.309754
# Got request params and sorted out geometry constraints: 0:00:00.020643
# 3776 records available
# Downloaded records: 0:00:16.621170
# basisOfRecord                                HUMAN_OBSERVATION
# collectionCode                                    Observations
# coordinateUncertaintyInMeters                          UNKNOWN
# dataGeneralizations                                    UNKNOWN
# datasetName                      iNaturalist research-grade...
# latitude                                             38.205727
# longitude                                          -122.754494
# establishmentMeans                                     UNKNOWN
# occurrenceDate                             2020-01-01T16:45:41
# eventRemarks                                           UNKNOWN
# footprintWKT                                           UNKNOWN
# occ_id                                              2543085638
# identificationQualifier                                UNKNOWN
# individualCount                                        UNKNOWN
# institutionCode                                    iNaturalist
# institutionID                                          UNKNOWN
# issues                           ['COORDINATE_ROUNDED', 'GE...
# locality                                               UNKNOWN
# locationRemarks                                        UNKNOWN
# occurrenceRemarks                                      UNKNOWN
# samplingProtocol                                       UNKNOWN
# scientificName                   Taricha torosa (Rathke, 1833)
# Name: 0, dtype: object
# ['UNKNOWN' '32.0' '5.0' '10.0' '161.0' '6.0' '65.0' '8.0' '4425.0' '18.0'
#  '12.0' '24.0' '100.0' '16.0' '31.0' '1000.0' '4.0' '96.0' '30.0' '3000.0'
#  '28677.0' '28329.0' '28388.0' '14.0' '167.0' '25.0' '645.0' '10518.0'
#  '94130.0' '13.0' '50.0' '11.0' '115.0' '181.0' '263.0' '29.0' '15.0'
#  '3579.0' '28417.0' '27.0' '1381.0' '205.0' '2000.0' '791.0' '73.0' '83.0'
#  '7.0' '22.0' '165.0' '204.0' '37.0' '35.0' '729.0' '1568.0' '23.0'
#  '526.0' '1127.0' '6000.0' '1728.0' '19.0' '3802.0' '1401.0' '158.0'
#  '298.0' '431.0' '102.0' '6346.0' '28255.0' '89.0' '309.0' '863.0'
#  '7165.0' '213.0' '28860.0' '325.0' '8122.0' '28804.0' '5504.0' '130.0'
#  '28916.0' '331.0' '4128.0' '943.0' '41.0' '793.0' '28832.0' '477.0'
#  '201.0' '258.0' '7060.0' '1147.0' '8256.0' '10000.0' '8126.0' '226.0'
#  '52.0' '155.0' '291.0' '518.0' '333.0' '709.0' '196.0' '1315.0' '1428.0'
#  '837.0' '131.0' '3575.0' '3143.0' '1457.0' '97.0' '457.0' '2064.0' '86.0'
#  '288.0' '1549.0' '826.0' '15622.0' '500292.0' '2889.0' '654.0' '1589.0'
#  '29025.0' '55115.0' '4983.0' '170.0' '153.0' '208.0' '3514.0' '203.0'
#  '210.0' '833.0' '1803.0' '189.0' '2709.0' '418.0' '368.0' '160.0'
#  '5005.0' '964.0' '243.0' '615.0' '2977.0' '106.0' '8804.0' '5283.0'
#  '737.0' '3864.0' '197.0' '2027.0' '302.0' '274.0' '487.0' '28957.0'
#  '313.0' '145.0' '1986.0' '88056.0' '39.0' '621.0' '3636.0' '632.0'
#  '5688.0' '1781.0' '127.0' '703.0' '486.0' '1713.0' '4063.0' '11495.0'
#  '292.0' '275.0' '150.0' '27212.0' '1485.0' '220.0' '2576.0' '1519.0'
#  '1228.0' '651.0' '3342.0' '221.0' '7324.0' '303.0' '3380.0' '1747.0'
#  '1028.0' '737735.0' '12008.0' '2039.0' '2851.0' '422.0' '3386.0' '270.0'
#  '340.0' '927.0' '149000.0' '1330.0' '891.0' '1890.0' '5018.0' '319.0'
#  '8522.0' '811.0' '1299.0' '367.0' '12150.0' '5322.0' '7981.0' '1731.0'
#  '3854.0' '6841.0' '1629.0' '1796.0' '456.0' '3283.0' '283.0' '1718.0'
#  '342.0' '1289.0' '809.0' '21.57' '31.57' '689.0' '333.13' '976.87'
#  '102.95' '96.56' '228.47' '1483.76' '1480.6' '228.0' '1480.0' '334.74'
#  '418.43' '1384.04' '595.46' '28.59' '90.0' '4036.0' '1013.62' '1641.53'
#  '2012.0' '188.6' '2466.0' '173.0' '128.75' '169.0' '1013.61' '560.0']
# Summarized fields returned: 0:01:47.526870
# Created summary table of request results: 0:00:00.031258
# Performed post-request filtering: 0:00:00.018920
# Calculated new columns, deleted some too: 0:00:00.019915
# 338 duplicate records dropped: 0:00:01.496486
# Inserted records into table: 0:00:00.172214
# Summarized unique values retained: 0:00:00
# Updated occurrences table geometry column: 0:00:00.887878
# Buffered points: 0:00:02.514950
# Exported shapefile: 0:00:00.545686
#
# Records saved in T:/temp/acfnex0mattTestmattTest.sqlite

# %% [markdown]
# ### Connect to output database, record species and filter info.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
sp_df.to_sql(name='species_concept', con=conn_occ, if_exists='replace')
request_df.to_sql(name=gbif_req_id, con=conn_occ, if_exists='replace')
filter_df.to_sql(name=gbif_filter_id, con=conn_occ, if_exists='replace')

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 3022 records

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#   institutionCode                 collectionCode                    datasetName     0
# 0             CAS                           HERP                        UNKNOWN    80
# 1           CCBER                          Herps                        UNKNOWN     9
# 2            LACM                          Herps               LACM Vertebrates    12
# 3             MVZ  Amphibian and reptile spec...                        UNKNOWN   309
# 4           SBMNH                             HE                        UNKNOWN     7
# 5         UNKNOWN                        UNKNOWN                        UNKNOWN     3
# 6            USNM          Amphibians & Reptiles            NMNH Extant Biology     9
# 7     iNaturalist                   Observations  iNaturalist research-grade...  3346
# 8     naturgucker                    naturgucker                        UNKNOWN     1

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#   institutionCode                 collectionCode                    datasetName  COUNT(occ_id)
# 0             CAS                           HERP                        UNKNOWN             59
# 1           CCBER                          Herps                        UNKNOWN              8
# 2            LACM                          Herps               LACM Vertebrates              8
# 3             MVZ  Amphibian and reptile spec...                        UNKNOWN             45
# 4           SBMNH                             HE                        UNKNOWN              5
# 5         UNKNOWN                        UNKNOWN                        UNKNOWN              3
# 6            USNM          Amphibians & Reptiles            NMNH Extant Biology              5
# 7     iNaturalist                   Observations  iNaturalist research-grade...           2888
# 8     naturgucker                    naturgucker                        UNKNOWN              1

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#         basisOfRecord  count
# 0   HUMAN_OBSERVATION   3348
# 1     MATERIAL_SAMPLE      6
# 2  PRESERVED_SPECIMEN    422

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#         basisOfRecord  count
# 0   HUMAN_OBSERVATION   2890
# 1     MATERIAL_SAMPLE      2
# 2  PRESERVED_SPECIMEN    130

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
#   samplingProtocol  count
# 0          UNKNOWN   3776

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#   samplingProtocol  count
# 0          UNKNOWN   3022

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                              issues  count
# 0                                 ['COORDINATE_REPROJECTED', 'TYPE_STATUS_INVALID']      1
# 1                                                        ['COORDINATE_REPROJECTED']    110
# 2           ['COORDINATE_ROUNDED', 'COORDINATE_REPROJECTED', 'TYPE_STATUS_INVALID']      1
# 3                                  ['COORDINATE_ROUNDED', 'COORDINATE_REPROJECTED']     39
# 4   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84', 'COORDINATE_UNCERTAIN...      1
# 5                            ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84']   2725
# 6   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS...      8
# 7                                                            ['COORDINATE_ROUNDED']     37
# 8              ['GEODETIC_DATUM_ASSUMED_WGS84', 'COUNTRY_DERIVED_FROM_COORDINATES']      1
# 9                                                  ['GEODETIC_DATUM_ASSUMED_WGS84']    642
# 10                       ['GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS84']    188
# 11                                                                               []     23

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                                                              issues  count
# 0                                                                                       17
# 1                                                            COORDINATE_REPROJECTED     16
# 2                                        COORDINATE_REPROJECTED;TYPE_STATUS_INVALID      1
# 3                                                                COORDINATE_ROUNDED     28
# 4                                         COORDINATE_ROUNDED;COORDINATE_REPROJECTED     27
# 5                     COORDINATE_ROUNDED;COORDINATE_REPROJECTED;TYPE_STATUS_INVALID      1
# 6                                   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84   2297
# 7   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METER...      1
# 8            COORDINATE_ROUNDED;GEODETIC_DATUM_INVALID;GEODETIC_DATUM_ASSUMED_WGS84      6
# 9                                                      GEODETIC_DATUM_ASSUMED_WGS84    606
# 10                    GEODETIC_DATUM_ASSUMED_WGS84;COUNTRY_DERIVED_FROM_COORDINATES      1
# 11                              GEODETIC_DATUM_INVALID;GEODETIC_DATUM_ASSUMED_WGS84     21

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
try:
    functions.MapShapefilePolygons(map_these=map_these, title=title)
except Exception as e:
    print("Unable to map:  " + str(e))
# Out:
# T:/code/wildlife-wrangler\wrangler_functions.py:41: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   height=3200000, width=5000000)
# T:/code/wildlife-wrangler\wrangler_functions.py:43: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawstates(color='grey')
# T:/code/wildlife-wrangler\wrangler_functions.py:44: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawcountries(color='grey')
# T:/code/wildlife-wrangler\wrangler_functions.py:55: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   color=mapfile['linecolor'])

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty - Zoomed In")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty - Zoomed In')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# NATIVE, UNKNOWN

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# A, UNKNOWN

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                                attribute  included(n)  populated(n)
# Field
# 0                                 acceptedScientificName         3776          3776
# 1                                       acceptedTaxonKey         3776          3776
# 2                                           accessRights          321           321
# 3                                    associatedSequences            4             4
# 4                                          basisOfRecord         3776          3776
# 5                                  bibliographicCitation           12            12
# 6                                          catalogNumber         3769          3769
# 7                                                  class         3776          3776
# 8                                               classKey         3776          3776
# 9                                         collectionCode         3773          3773
# 10                                          collectionID          321           321
# 11                                             continent          426           426
# 12                         coordinateUncertaintyInMeters         2763          2763
# 13                                               country         3776          3776
# 14                                           countryCode         3776          3776
# 15                                                county          426           426
# 16                                               crawlId         3776          3776
# 17                                               created            1             1
# 18                                   dataGeneralizations            1             1
# 19                                            datasetKey         3776          3776
# 20                                           datasetName         3367          3367
# 21                                        dateIdentified         3340          3340
# 22                                                   day         3774          3774
# 23                                       decimalLatitude         3776          3776
# 24                                      decimalLongitude         3776          3776
# 25                                     dynamicProperties          309           309
# 26                                             elevation          137           137
# 27                                     elevationAccuracy           72            72
# 28                                          endDayOfYear          243           243
# 29                                    establishmentMeans           28            28
# 30                                             eventDate         3776          3776
# 31                                             eventTime         3084          3084
# 32                                            extensions         3776             0
# 33                                                 facts         3776             0
# 34                                                family         3776          3776
# 35                                             familyKey         3776          3776
# 36                                                gbifID         3776          3776
# 37                                           genericName         3776          3776
# 38                                                 genus         3776          3776
# 39                                              genusKey         3776          3776
# 40                                         geodeticDatum         3776          3776
# 41                                  georeferenceProtocol          316           316
# 42                                   georeferenceRemarks            6             6
# 43                                   georeferenceSources          353           353
# 44                        georeferenceVerificationStatus          337           337
# 45                                       georeferencedBy          309           309
# 46                                     georeferencedDate          309           309
# 47                                               habitat           61            61
# 48                                  higherClassification          427           427
# 49                                       higherGeography          426           426
# 50         http://rs.tdwg.org/dwc/terms/organismQuantity           12            12
# 51     http://rs.tdwg.org/dwc/terms/organismQuantityType           12            12
# 52                           http://unknown.org/language            1             1
# 53                               http://unknown.org/nick         3346          3346
# 54                  http://unknown.org/occurrenceDetails         3346          3346
# 55                             http://unknown.org/rights            1             1
# 56                       http://unknown.org/rightsHolder            1             1
# 57                                      identificationID         3252          3252
# 58                               identificationQualifier          309           309
# 59                                 identificationRemarks          346           346
# 60                      identificationVerificationStatus          309           309
# 61                                          identifiedBy          389           389
# 62                                       identifiedByIDs         3776            76
# 63                                            identifier         3775          3775
# 64                                           identifiers         3776             0
# 65                                       individualCount          346           346
# 66                                   informationWithheld          485           485
# 67                                  infraspecificEpithet           60            60
# 68                                       installationKey         3776          3776
# 69                                       institutionCode         3773          3773
# 70                                         institutionID          417           417
# 71                                                issues         3776          3753
# 72                                                   key         3776          3776
# 73                                               kingdom         3776          3776
# 74                                            kingdomKey         3776          3776
# 75                                              language          417           417
# 76                                           lastCrawled         3776          3776
# 77                                       lastInterpreted         3776          3776
# 78                                            lastParsed         3776          3776
# 79                                               license         3776          3776
# 80                                             lifeStage          107           107
# 81                                              locality          429           429
# 82                                   locationAccordingTo          309           309
# 83                                       locationRemarks            2             2
# 84                                                 media         3776          2964
# 85                                              modified         3764          3764
# 86                                                 month         3776          3776
# 87                                           networkKeys          309           309
# 88                                     nomenclaturalCode          337           337
# 89                                          occurrenceID         3775          3775
# 90                                     occurrenceRemarks          945           945
# 91                                      occurrenceStatus           29            29
# 92                                                 order         3776          3776
# 93                                              orderKey         3776          3776
# 94                                            organismID          309           309
# 95                                      organismQuantity           12            12
# 96                                  organismQuantityType           12            12
# 97                                   otherCatalogNumbers          296           296
# 98                                                phylum         3776          3776
# 99                                             phylumKey         3776          3776
# 100                                         preparations          412           412
# 101                              previousIdentifications          309           309
# 102                                             protocol         3776          3776
# 103                                    publishingCountry         3775          3775
# 104                                     publishingOrgKey         3776          3776
# 105                                         recordNumber          392           392
# 106                                           recordedBy         3760          3760
# 107                                        recordedByIDs         3776            67
# 108                                           references         3669          3669
# 109                                            relations         3776             0
# 110                                               rights         3346          3346
# 111                                         rightsHolder         3346          3346
# 112                                       scientificName         3776          3776
# 113                                                  sex           27            27
# 114                                              species         3776          3776
# 115                                           speciesKey         3776          3776
# 116                                      specificEpithet         3776          3776
# 117                                       startDayOfYear           35            35
# 118                                        stateProvince         3773          3773
# 119                                              taxonID         3347          3347
# 120                                             taxonKey         3776          3776
# 121                                            taxonRank         3776          3776
# 122                                      taxonomicStatus         3776          3776
# 123                                                 type          426           426
# 124                             verbatimCoordinateSystem          342           342
# 125                                    verbatimElevation           60            60
# 126                                    verbatimEventDate         3756          3756
# 127                                     verbatimLocality         3694          3694
# 128                                                 year         3776          3776

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:02:17.057902
