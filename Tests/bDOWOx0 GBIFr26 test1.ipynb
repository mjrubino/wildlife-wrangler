# %% [markdown]
# # Downy Woodpecker recent test
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### Set Variables - fill out stuff in this cell.
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
species_id = 'bdowox0'
summary_name = 'bdowox1curr'
gbif_req_id = 'GBIFr26'
gbif_filter_id = 'test1'
default_coordUncertainty = 1000       # Note above.
workDir = 'T:/Occurrence_Records/'   # Be sure to create folders named "Inputs" and "Outputs" here.
codeDir = 'T:/Code/wildlife-wrangler'
paramdb = 'P:/Proj3/USGap/Vert/DBase/wildlife-wrangler.sqlite'
configDir = 'T:/GAP/Data/'  # Path to folder where saved your wildlifeconfig file.

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temp fix, hopefully.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410

# %%
import os
os.environ['PROJ_LIB'] = r'c:\Users\nmtarr\AppData\Local\Continuum\miniconda3\envs\wrangler\Library\share'

# %% [markdown]
# ### Setup - nothing to fill out in this cell

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
sys.path.append(codeDir)
import repo_functions as functions
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
spdb = outDir + species_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
gap_id = connjup.execute("""SELECT gap_id
                            FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM species_concepts WHERE species_id = '{0}'""".format(species_id)).fetchone()[0]
# Out:
# Notebook run 2020-03-24 17:01:40.379784
# T:/Occurrence_Records/Outputs/bdowox0GBIFr26test1.sqlite

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
sp_dict = dict(zip(cols, vals))
sp_df = pd.DataFrame.from_dict(sp_dict, orient='index', columns=['VALUE'])
sp_df.index.name = 'ATTRIBUTE'
print("SPECIES CONCEPT RECORD")
print(sp_df)
# Out:
# SPECIES CONCEPT RECORD
#                                         VALUE
# ATTRIBUTE
# species_id                            bdowox0
# fws_id                                   None
# gap_id                                 bdowox
# itis_tsn                               178259
# gbif_id                               2477781
# bcb_id                                   None
# ebird_id                                 None
# common_name                  downy woodpecker
# scientific_name            Picoides pubescens
# start_year                               None
# split_from                               None
# end_year                                 2018
# lumped_into                           bdowox1
# geometry                                 None
# detection_distance_meters                 200
# vetted_how                 Consulted avibase.
# vetted_who                            N. Tarr
# vetted_date                         3/10/2020
# notes                                    None

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
request_df = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(request_df.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                            GBIFr26
# source                                   GBIF
# lat_range                                None
# lon_range                                None
# years_range                         1990,2015
# months_range                             1,12
# geoissue                                False
# coordinate                               True
# country                                    US
# geometry                                 None
# creator                               N. Tarr
# notes           Built for GAP v2 range map...
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
filter_df = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(filter_df.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                     test1
# dataset                        GBIF
# institutions_omit              None
# collection_codes_omit          None
# datasets_omit                  None
# has_coordinate_uncertainty        0
# max_coordinate_uncertainty    10000
# bases_omit                     None
# sampling_protocols_omit        None
# issues_omit                    None
# duplicates_OK                 False
# creator                        None
# notes                          None
# Name: 0, dtype: object

# %% [markdown]
# ## Filter set justification - ENTER your justification for the following settings.
#
# **default_coord_uncertainty:**
#
# **years_range:**
#
# **months_range:**
#
# **geoissue:**
#
# **coordinate:**
#
# **country:**
#
# **geometry:**
#
# **collection_codes_omit:**
#
# **institutions_omit:**
#
# **datasets_omit:**
#
# **has_coordinate_uncertainty:**
#
# **max_coordinate_uncertainty:**
#
# **bases_omit:**
#
# **sampling_protocols_omit:**
#
# **issues_omit:**
#
# **duplicates:**

# %%
functions.retrieve_gbif_occurrences(codeDir, species_id, inDir, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                   password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.382569
# Got request params and sorted out geometry constraints: 0:00:00.003979
# 260202 records available
# Your download key is  0029145-200221144449610
# Downloading Darwin Core Archive zip file for this species .....
# Download file size: 40027645 bytes
# On disk at T:/Occurrence_Records/Inputs//0029145-200221144449610.zip
# Download complete: 0:17:45.392825
# basisOfRecord                     object
# collectionCode                    object
# coordinateUncertaintyInMeters    float64
# dataGeneralizations               object
# datasetName                       object
# latitude                         float64
# longitude                        float64
# establishmentMeans                object
# occurrenceDate                    object
# eventRemarks                      object
# footprintWKT                     float64
# occ_id                             int64
# identificationQualifier           object
# individualCount                  float64
# institutionCode                   object
# institutionID                     object
# issues                            object
# locality                          object
# locationRemarks                   object
# occurrenceRemarks                 object
# samplingProtocol                  object
# scientificName                    object
# dtype: object
# basisOfRecord                     object
# collectionCode                    object
# coordinateUncertaintyInMeters    float64
# dataGeneralizations               object
# datasetName                       object
# latitude                          object
# longitude                         object
# establishmentMeans                object
# occurrenceDate                    object
# eventRemarks                      object
# footprintWKT                     float64
# occ_id                             int64
# identificationQualifier           object
# individualCount                  float64
# institutionCode                   object
# institutionID                     object
# issues                            object
# locality                          object
# locationRemarks                   object
# occurrenceRemarks                 object
# samplingProtocol                  object
# scientificName                    object
# dtype: object
# Downloaded and loaded records: 0:00:13.832725
# Summarized fields returned: 0:00:01.154295
# Created summary table of request results: 0:00:00.261094
# Performed post-request filtering: 0:00:00.546797
# Calculated new columns, deleted some too: 0:00:00.485405
# 79260 duplicate records dropped: 1:04:09.611486
# Inserted records into table: 0:00:05.027273
# Summarized unique values retained: 0:00:00.069106
# Updated occurrences table geometry column: 0:00:51.128695
# Buffered points: 0:01:58.533198
# Exported maps: 0:00:44.212273
#
# Records saved in T:/Occurrence_Records/Outputs/bdowox0GBIFr26test1.sqlite

# %% [markdown]
# ### Connect to output database, record species and filter info.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
sp_df.to_sql(name='species_concept', con=conn_occ, if_exists='replace')
request_df.to_sql(name=gbif_req_id, con=conn_occ, if_exists='replace')
filter_df.to_sql(name=gbif_filter_id, con=conn_occ, if_exists='replace')

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 180904 records

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#                   institutionCode                 collectionCode                    datasetName       0
# 0                            AMNH                          Birds           AMNH Bird Collection      31
# 1                           ASNHC                          Birds  Angelo State Natural Histo...       1
# 2                     Anymals.org                     user: 1475  Anymals+plants - Citizen S...       1
# 3                     Anymals.org                     user: 5465  Anymals+plants - Citizen S...       1
# 4                     Anymals.org                     user: 6025  Anymals+plants - Citizen S...       1
# 5                     Anymals.org                     user: 7136  Anymals+plants - Citizen S...       1
# 6   BSC; Bird Studies Canada -...  MMP; Marsh Monitoring Prog...  Marsh Monitoring Program -...      93
# 7   Borror Laboratory of Bioac...                     Recordings  Borror Lab of Bioacoustics...      62
# 8                             CAS                            ORN          CAS Ornithology (ORN)       5
# 9                            CHAS                 Bird specimens      CHAS Ornithology (Arctos)       2
# 10                            CLO                           GBBC      Great Backyard Bird Count  257427
# 11                            CLO                             ML  Macaulay Library Audio and...      75
# 12                           CMNH                          Birds          CMNH Birds Collection       3
# 13                           CUMV                           Bird           CUMV Bird Collection      33
# 14                           DMNH                           Bird                     DMNH Birds      18
# 15                           DMNS                 Bird specimens  DMNS Bird Collection (Arctos)      25
# 16                           FMNH                          Birds  Field Museum of Natural Hi...       1
# 17                            ISU                          Birds                      ISU Birds       9
# 18                             KU                          Birds    KUBI Ornithology Collection       9
# 19                           LACM                          Birds     LACM Vertebrate Collection       1
# 20                            MCZ                            Orn  Museum of Comparative Zool...      10
# 21                           MMNH                           Bird              Bell Museum birds      11
# 22                            MSB                 Bird specimens   MSB Bird Collection (Arctos)      29
# 23                           NYSM                             ZO                     NYSM Birds       1
# 24                           OMNH                          Birds                Birds Specimens       5
# 25  Ohio State University - Bi...                          Birds  Ohio State University Tetr...       2
# 26                           PRBO                        PRBO-PC  Point Reyes Bird Observato...    1840
# 27                            PSM                           Bird     PSM Vertebrates Collection      35
# 28                            RSL                             PC  U.S.D.A. Forest Service, R...     352
# 29                          SBMNH                             AV       SBMNH Vertebrate Zoology       6
# 30                          SBMNH                             OS       SBMNH Vertebrate Zoology       1
# 31                          SDNHM                          Birds         SDNHM Birds Collection       1
# 32                           TCWC                          Birds  Biodiversity Research and ...       4
# 33                            UAM                 Bird specimens   UAM Bird Collection (Arctos)      25
# 34                           UMMZ                          birds  University of Michigan Mus...      23
# 35                           USNM                          Birds   NMNH Extant Specimen Records       2
# 36                           UWBM                           Bird    UWBM Ornithology Collection      49
# 37                           WFVZ                           Bird          WFVZ Bird Collections       1

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#                   institutionCode                 collectionCode                    datasetName  COUNT(occ_id)
# 0                            None                           None                      Bioimages              1
# 1                            None                           None  Geographically tagged INSD...              4
# 2                            AMNH                          Birds           AMNH Bird Collection             11
# 3                           ASNHC                          Birds  Angelo State Natural Histo...              1
# 4                     Anymals.org                     user: 1475  Anymals+plants - Citizen S...              1
# 5                     Anymals.org                     user: 5465  Anymals+plants - Citizen S...              1
# 6                     Anymals.org                     user: 6025  Anymals+plants - Citizen S...              1
# 7                     Anymals.org                     user: 7136  Anymals+plants - Citizen S...              1
# 8   BSC; Bird Studies Canada -...  MMP; Marsh Monitoring Prog...  Marsh Monitoring Program -...             76
# 9   Borror Laboratory of Bioac...                     Recordings  Borror Lab of Bioacoustics...             38
# 10                            CAS                            ORN          CAS Ornithology (ORN)              5
# 11                           CHAS                 Bird specimens      CHAS Ornithology (Arctos)              2
# 12                            CLO                           GBBC      Great Backyard Bird Count         178549
# 13                            CLO                             ML  Macaulay Library Audio and...             42
# 14                           CMNH                          Birds          CMNH Birds Collection              3
# 15                           CUMV                           Bird           CUMV Bird Collection             32
# 16                           DMNH                           Bird                     DMNH Birds             17
# 17                           DMNS                 Bird specimens  DMNS Bird Collection (Arctos)             24
# 18                           FMNH                          Birds  Field Museum of Natural Hi...              1
# 19                            ISU                          Birds                      ISU Birds              9
# 20                             KU                          Birds    KUBI Ornithology Collection              9
# 21                           LACM                          Birds     LACM Vertebrate Collection              1
# 22                            MCZ                            Orn  Museum of Comparative Zool...             10
# 23                           MMNH                           Bird              Bell Museum birds              8
# 24                            MSB                 Bird specimens   MSB Bird Collection (Arctos)             24
# 25                           NYSM                             ZO                     NYSM Birds              1
# 26                           OMNH                          Birds                Birds Specimens              3
# 27  Ohio State University - Bi...                          Birds  Ohio State University Tetr...              2
# 28                           PRBO                        PRBO-PC  Point Reyes Bird Observato...           1607
# 29                            PSM                           Bird     PSM Vertebrates Collection             28
# 30                            RSL                             PC  U.S.D.A. Forest Service, R...            314
# 31                          SBMNH                             AV       SBMNH Vertebrate Zoology              6
# 32                          SBMNH                             OS       SBMNH Vertebrate Zoology              1
# 33                          SDNHM                          Birds         SDNHM Birds Collection              1
# 34                           TCWC                          Birds  Biodiversity Research and ...              3
# 35                            UAM                 Bird specimens   UAM Bird Collection (Arctos)              1
# 36                           UMMZ                          birds  University of Michigan Mus...             22
# 37                           USNM                          Birds   NMNH Extant Specimen Records              2
# 38                           UWBM                           Bird    UWBM Ornithology Collection             41
# 39                           WFVZ                           Bird          WFVZ Bird Collections              1

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#          basisOfRecord   count
# 0    HUMAN_OBSERVATION      67
# 1  MACHINE_OBSERVATION      75
# 2          OBSERVATION  259712
# 3   PRESERVED_SPECIMEN     348

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#          basisOfRecord   count
# 0    HUMAN_OBSERVATION      43
# 1  MACHINE_OBSERVATION      42
# 2          OBSERVATION  180546
# 3   PRESERVED_SPECIMEN     273

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
#            samplingProtocol  count
# 0                      Shot      2
# 1                   Shotgun     19
# 2               Window Kill      1
# 3            none specified     64
# 4                   salvage     11
# 5        salvage-cat caught      1
# 6                  salvaged      8
# 7   salvaged - dead on road      1
# 8    salvaged - window kill      1
# 9                      shot     12
# 10              window kill      1
# 11            window strike      1

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#            samplingProtocol   count
# 0                      None  180822
# 1                      Shot       1
# 2                   Shotgun       7
# 3               Window Kill       1
# 4            none specified      40
# 5                   salvage      10
# 6        salvage-cat caught       1
# 7                  salvaged       7
# 8   salvaged - dead on road       1
# 9    salvaged - window kill       1
# 10                     shot      11
# 11              window kill       1
# 12            window strike       1

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                     issues   count
# 0                                                   COORDINATE_REPROJECTED       1
# 1                                                       COORDINATE_ROUNDED     193
# 2                      COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDINATES       1
# 3                          COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84   24734
# 4   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       4
# 5                            COORDINATE_ROUNDED;PRESUMED_NEGATED_LONGITUDE       1
# 6                                         COUNTRY_DERIVED_FROM_COORDINATES       3
# 7            COUNTRY_DERIVED_FROM_COORDINATES;GEODETIC_DATUM_ASSUMED_WGS84       5
# 8                                             GEODETIC_DATUM_ASSUMED_WGS84  234716
# 9                GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_PRECISION_INVALID     352
# 10                     GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       5
# 11                               RECORDED_DATE_MISMATCH;COORDINATE_ROUNDED       1
# 12                                                  TAXON_MATCH_HIGHERRANK       9

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                                                     issues   count
# 0                                                                              116
# 1                                                   COORDINATE_REPROJECTED       1
# 2                                                       COORDINATE_ROUNDED     159
# 3                      COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDINATES       1
# 4                          COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84   15400
# 5   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       4
# 6                            COORDINATE_ROUNDED;PRESUMED_NEGATED_LONGITUDE       1
# 7                                         COUNTRY_DERIVED_FROM_COORDINATES       3
# 8            COUNTRY_DERIVED_FROM_COORDINATES;GEODETIC_DATUM_ASSUMED_WGS84       4
# 9                                             GEODETIC_DATUM_ASSUMED_WGS84  164896
# 10               GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_PRECISION_INVALID     314
# 11                     GEODETIC_DATUM_ASSUMED_WGS84;GEODETIC_DATUM_INVALID       4
# 12                               RECORDED_DATE_MISMATCH;COORDINATE_ROUNDED       1

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)
# Out:
# T:/Code/wildlife-wrangler\repo_functions.py:42: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   height=3200000, width=5000000)
# T:/Code/wildlife-wrangler\repo_functions.py:44: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawstates(color='grey')
# T:/Code/wildlife-wrangler\repo_functions.py:45: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   map.drawcountries(color='grey')
# T:/Code/wildlife-wrangler\repo_functions.py:56: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   color=mapfile['linecolor'])

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty - Zoomed In")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty - Zoomed In')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# NATIVE, MANAGED, nan

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# nan, A

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                  attribute  included(n)  populated(n)
# Field
# 0                                 abstract       260202             0
# 1                             accessRights       260202           323
# 2                            accrualMethod       260202             0
# 3                       accrualPeriodicity       260202             0
# 4                            accrualPolicy       260202             0
# 5                              alternative       260202             0
# 6                                 audience       260202             0
# 7                                available       260202             0
# 8                    bibliographicCitation       260202            42
# 9                               conformsTo       260202             0
# 10                             contributor       260202             0
# 11                                coverage       260202             0
# 12                                 created       260202             5
# 13                                 creator       260202             0
# 14                                    date       260202             0
# 15                            dateAccepted       260202             0
# 16                         dateCopyrighted       260202             0
# 17                           dateSubmitted       260202             0
# 18                             description       260202             0
# 19                          educationLevel       260202             0
# 20                                  extent       260202             0
# 21                                  format       260202             0
# 22                               hasFormat       260202             0
# 23                                 hasPart       260202             0
# 24                              hasVersion       260202             0
# 25                              identifier       260202        260188
# 26                     instructionalMethod       260202             0
# 27                              isFormatOf       260202             0
# 28                                isPartOf       260202             0
# 29                          isReferencedBy       260202             0
# 30                            isReplacedBy       260202             0
# 31                            isRequiredBy       260202             0
# 32                             isVersionOf       260202             0
# 33                                  issued       260202             0
# 34                                language       260202           430
# 35                                 license       260202        260202
# 36                                mediator       260202             0
# 37                                  medium       260202             0
# 38                                modified       260202           477
# 39                              provenance       260202             0
# 40                               publisher       260202        260202
# 41                              references       260202           338
# 42                                relation       260202             0
# 43                                replaces       260202             0
# 44                                requires       260202             0
# 45                                  rights       260202            86
# 46                            rightsHolder       260202            22
# 47                                  source       260202             0
# 48                                 spatial       260202             0
# 49                                 subject       260202             0
# 50                         tableOfContents       260202             0
# 51                                temporal       260202             0
# 52                                   title       260202             0
# 53                                    type       260202           367
# 54                                   valid       260202             0
# 55                           institutionID       260202           362
# 56                            collectionID       260202           238
# 57                               datasetID       260202             1
# 58                         institutionCode       260202        260196
# 59                          collectionCode       260202        260196
# 60                             datasetName       260202        260202
# 61                    ownerInstitutionCode       260202            11
# 62                           basisOfRecord       260202        260202
# 63                     informationWithheld       260202            26
# 64                     dataGeneralizations       260202             1
# 65                       dynamicProperties       260202           163
# 66                            occurrenceID       260202           446
# 67                           catalogNumber       260202        260196
# 68                            recordNumber       260202            70
# 69                              recordedBy       260202           547
# 70                         individualCount       260202           240
# 71                        organismQuantity       260202             0
# 72                    organismQuantityType       260202             0
# 73                                     sex       260202           337
# 74                               lifeStage       260202           122
# 75                   reproductiveCondition       260202            25
# 76                                behavior       260202            75
# 77                      establishmentMeans       260202           270
# 78                        occurrenceStatus       260202           268
# 79                            preparations       260202           329
# 80                             disposition       260202            31
# 81                    associatedReferences       260202             0
# 82                     associatedSequences       260202             5
# 83                          associatedTaxa       260202            43
# 84                     otherCatalogNumbers       260202           116
# 85                       occurrenceRemarks       260202           199
# 86                              organismID       260202            83
# 87                            organismName       260202             0
# 88                           organismScope       260202             0
# 89                   associatedOccurrences       260202             2
# 90                     associatedOrganisms       260202             0
# 91                 previousIdentifications       260202            82
# 92                         organismRemarks       260202             2
# 93                        materialSampleID       260202             0
# 94                                 eventID       260202             0
# 95                           parentEventID       260202             0
# 96                             fieldNumber       260202            42
# 97                               eventDate       260202        260202
# 98                               eventTime       260202             1
# 99                          startDayOfYear       260202           269
# 100                           endDayOfYear       260202           327
# 101                                   year       260202        260202
# 102                                  month       260202        260202
# 103                                    day       260202        260178
# 104                      verbatimEventDate       260202           376
# 105                                habitat       260202            29
# 106                       samplingProtocol       260202           122
# 107                         samplingEffort       260202             0
# 108                        sampleSizeValue       260202             0
# 109                         sampleSizeUnit       260202             0
# 110                             fieldNotes       260202            64
# 111                           eventRemarks       260202            19
# 112                             locationID       260202             0
# 113                      higherGeographyID       260202             0
# 114                        higherGeography       260202           399
# 115                              continent       260202           758
# 116                              waterBody       260202             7
# 117                            islandGroup       260202            10
# 118                                 island       260202             5
# 119                            countryCode       260202        260202
# 120                          stateProvince       260202        260192
# 121                                 county       260202        259943
# 122                           municipality       260202             0
# 123                               locality       260202        259805
# 124                       verbatimLocality       260202           360
# 125                      verbatimElevation       260202            53
# 126                          verbatimDepth       260202             0
# 127    minimumDistanceAboveSurfaceInMeters       260202             0
# 128    maximumDistanceAboveSurfaceInMeters       260202             0
# 129                    locationAccordingTo       260202            81
# 130                        locationRemarks       260202             6
# 131                        decimalLatitude       260202        260202
# 132                       decimalLongitude       260202        260202
# 133          coordinateUncertaintyInMeters       260202           286
# 134                    coordinatePrecision       260202             0
# 135                  pointRadiusSpatialFit       260202             0
# 136               verbatimCoordinateSystem       260202           120
# 137                            verbatimSRS       260202             0
# 138                           footprintWKT       260202             0
# 139                           footprintSRS       260202             0
# 140                    footprintSpatialFit       260202             0
# 141                        georeferencedBy       260202           171
# 142                      georeferencedDate       260202           181
# 143                   georeferenceProtocol       260202           238
# 144                    georeferenceSources       260202           268
# 145         georeferenceVerificationStatus       260202           384
# 146                    georeferenceRemarks       260202            94
# 147                    geologicalContextID       260202             0
# 148            earliestEonOrLowestEonothem       260202             0
# 149             latestEonOrHighestEonothem       260202             0
# 150             earliestEraOrLowestErathem       260202             0
# 151              latestEraOrHighestErathem       260202             0
# 152           earliestPeriodOrLowestSystem       260202             0
# 153            latestPeriodOrHighestSystem       260202             0
# 154            earliestEpochOrLowestSeries       260202             0
# 155             latestEpochOrHighestSeries       260202             0
# 156               earliestAgeOrLowestStage       260202             0
# 157                latestAgeOrHighestStage       260202             0
# 158             lowestBiostratigraphicZone       260202             0
# 159            highestBiostratigraphicZone       260202             0
# 160                lithostratigraphicTerms       260202             0
# 161                                  group       260202             0
# 162                              formation       260202             0
# 163                                 member       260202             0
# 164                                    bed       260202             0
# 165                       identificationID       260202             0
# 166                identificationQualifier       260202            81
# 167                             typeStatus       260202             0
# 168                           identifiedBy       260202           108
# 169                         dateIdentified       260202           135
# 170               identificationReferences       260202             1
# 171       identificationVerificationStatus       260202            81
# 172                  identificationRemarks       260202            89
# 173                                taxonID       260202            16
# 174                       scientificNameID       260202            64
# 175                    acceptedNameUsageID       260202        260202
# 176                      parentNameUsageID       260202             0
# 177                    originalNameUsageID       260202             0
# 178                      nameAccordingToID       260202             0
# 179                      namePublishedInID       260202             0
# 180                         taxonConceptID       260202             0
# 181                         scientificName       260202        260202
# 182                      acceptedNameUsage       260202             0
# 183                        parentNameUsage       260202             0
# 184                      originalNameUsage       260202             0
# 185                        nameAccordingTo       260202             0
# 186                        namePublishedIn       260202             0
# 187                    namePublishedInYear       260202             0
# 188                   higherClassification       260202           329
# 189                                kingdom       260202        260202
# 190                                 phylum       260202        260202
# 191                                  class       260202        260202
# 192                                  order       260202        260202
# 193                                 family       260202        260202
# 194                                  genus       260202        260202
# 195                               subgenus       260202             0
# 196                        specificEpithet       260202        260202
# 197                   infraspecificEpithet       260202             0
# 198                              taxonRank       260202        260202
# 199                      verbatimTaxonRank       260202             0
# 200                         vernacularName       260202           130
# 201                      nomenclaturalCode       260202           360
# 202                        taxonomicStatus       260202        260202
# 203                    nomenclaturalStatus       260202             0
# 204                           taxonRemarks       260202             0
# 205                             datasetKey       260202        260202
# 206                      publishingCountry       260202        260202
# 207                        lastInterpreted       260202        260202
# 208                              elevation       260202           429
# 209                      elevationAccuracy       260202           398
# 210                                  depth       260202             0
# 211                          depthAccuracy       260202             0
# 212                   distanceAboveSurface       260202             0
# 213           distanceAboveSurfaceAccuracy       260202             0
# 214                                  issue       260202        260025
# 215                              mediaType       260202            62
# 216                          hasCoordinate       260202        260202
# 217                    hasGeospatialIssues       260202        260202
# 218                               taxonKey       260202        260202
# 219                       acceptedTaxonKey       260202        260202
# 220                             kingdomKey       260202        260202
# 221                              phylumKey       260202        260202
# 222                               classKey       260202        260202
# 223                               orderKey       260202        260202
# 224                              familyKey       260202        260202
# 225                               genusKey       260202        260202
# 226                            subgenusKey       260202             0
# 227                             speciesKey       260202        260202
# 228                                species       260202        260202
# 229                            genericName       260202        260202
# 230                 acceptedScientificName       260202        260202
# 231                 verbatimScientificName       260202             0
# 232                           typifiedName       260202        260202
# 233                               protocol       260202        260202
# 234                             lastParsed       260202        260202
# 235                            lastCrawled       260202        260202
# 236                            repatriated       260202             0
# 237               relativeOrganismQuantity       260202             0

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 1:27:18.161609
