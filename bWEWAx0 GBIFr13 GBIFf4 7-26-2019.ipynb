# %% [markdown]
# # Worm-eating Warbler - Occurrence Records Summary
# This notebook is a tool for exploring data sets requested from GBIF (and eventually other sources), and mostly for developing criteria for filtering records (filter sets).  When the entire notebook is run, it retrieves records according to the filter sets specified and saves the results (records and some summary tables) in an sqlite database.  Some information is pulled from the parameters.sqlite database that is saved in this repository.

# %% [markdown]
# ### General Setup

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
#import geopandas as gpd
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 60)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()

# %% [markdown]
# ### Config file
# Some of the scripts below pull variables from a config file.  This is in order to reduce redundancy and also facilitates running scripts outside of jupyter notebooks.  However, variables need to be able to be set in notebooks too, so the cell below deletes and then rewrites the config file according to what you want for running this notebook.

# %%
# Set variables in the following text string, not variable assignment below.
text = """#NOTE! this is overwritten by some notebooks, so update everywhere, if adding lines.
sp_id = 'bwewax0'
summary_name = 'wormie'
gbif_req_id = 'GBIFr13'
gbif_filter_id = 'GBIFf4'
ebird_req_id = None
ebird_filter_id = None
evaluation = 'eval_gbif1'
workDir = '/Users/nmtarr/Documents/Occurrences/'
codeDir = '/Users/nmtarr/Code/occurrence-record-wrangler/'
inDir = workDir + 'Inputs/'
outDir = workDir + 'Outputs/'
default_coordUncertainty = 500
SRID_dict = {'WGS84': 4326, 'AlbersNAD83': 102008} # Used in file names for output.
spdb = outDir + sp_id + gbif_req_id + gbif_filter_id + '.sqlite'
"""
f = open('config.py', 'w')
f.write(text)
f.close()

import config
species_id = config.sp_id
summary_name = config.summary_name
request_id = config.gbif_req_id
filter_id = config.gbif_filter_id
inDir = config.inDir
outDir = config.outDir
print("Notebook run " + str(t1))
# Out:
# Notebook run 2019-07-26 16:39:14.175656

# %%
connjup = sqlite3.connect(config.codeDir + 'parameters.sqlite')
cursorjup = connjup.cursor()

# %% [markdown]
# # Species Concept
# Display information on the species from the parameters.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM species_concepts WHERE species_id = '{0}';".format(species_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('species_concepts')").fetchall()]
pprint.pprint(dict(zip(cols, vals)))
# Out:
# {'bcb_id': None,
#  'breeding_months': '5,6,7,8',
#  'common_name': 'worm-eating warbler',
#  'detection_distance_meters': 200,
#  'end_year': None,
#  'error_tolerance': 20,
#  'fws_id': '',
#  'gap_id': 'bwewax',
#  'gbif_id': '2489603',
#  'geometry': None,
#  'itis_tsn': '726195',
#  'migratory': '1',
#  'notes': 'Species name changed from vermivorus at some point.',
#  'pad': 1,
#  'scientific_name': 'Helmitheros vermivorum',
#  'species_id': 'bwewax0',
#  'start_year': None,
#  'wintering_months': '12,1,2,'}

# %% [markdown]
# ## Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
df1 = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(request_id), con=connjup)
print("THE REQUEST FILTER SET")
print(df1.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                                                          GBIFr13
# source                                                                 GBIF
# lat_range                                                             27,41
# lon_range                                                           -91,-75
# years_range                                                       2010,2020
# months_range                                                            5,7
# geoissue                                                              False
# coordinate                                                             True
# continent                                                              None
# creator                                                                None
# notes           Good for somewhat recent data for migratory birds that b...
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the occurrence record sqlite database.

# %%
df2 = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(df2.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                                                          GBIFf4
# dataset                                                                              GBIF
# collection_codes_omit                                                                None
# institutions_omit                                                                    None
# has_coordinate_uncertainty                                                              0
# max_coordinate_uncertainty                                                           5000
# bases_omit                                            PRESERVED_SPECIMEN, FOSSIL_SPECIMEN
# protocols_omit                                                                       None
# sampling_protocols_omit                                                              None
# issues_omit                   GEODETIC_DATUM_INVALID, INDIVIDUAL_COUNT_INVALID, MULTIM...
# creator                                                                           N. Tarr
# notes                                                                                None
# Name: 0, dtype: object

# %% [markdown]
# ### Filter set justification
# default_coord_uncertainty: I chose 500 because eBird data is included, and traveling counts may be included as a point coordinate.
#
# years_range: I wanted current records, but not so many that runtime is slow.
#
# months_range: I wanted to minimize the inclusion of migrating birds.
#
# geoissue: Setting to False ensures exclusion of records with noted geoissues.
#
# coordinate: Setting to True ensures that records are only kept if they have a coordinate.
#
# continent: Setting to "North America" actually filters out lots of records, possibly just because the field is blank for those records.  Set to "None" for that reason.
#
# collection_codes_omit: --
#
# institutions_omit: --
#
# has_coordinate_uncertainty: Did not require this because it would omit ebird data.
#
# max_coordinate_uncertainty: No real logic behind the choice.
#
# bases_omit: Only interested in records of living animals, so omitted preserved specimens and fossils
#
# protocols_omit: --
#
# sampling_protocols_omit: --
#
# issues_omit: Invalid datums create spatial error in point locations.  Invalid counts seem like a red flag for data quality.

# %%
# Run a script that retrieves and filters
# %run 'retrieve_occurrences.py'
# Out:
# downloading https://www.sciencebase.gov/catalog/file/get/59f5ebb4e4b063d5d307e0d1?f=__disk__1c%2F00%2F75%2F1c00755f339c97bafe6c9d1c69ee14cef5326d7c to /Users/nmtarr/Documents/RANGES/Inputs/bWEWAx_CONUS_Range_2001v1.zip
# downloading https://www.sciencebase.gov/catalog/file/get/59f5ebb4e4b063d5d307e0d1?f=__disk__7c%2F1d%2Fc7%2F7c1dc7208c25d4ed06614642f32dbac70c2aa2d5 to /Users/nmtarr/Documents/RANGES/Inputs/bWEWAx_CONUS_Range_2001v1.xml
#
# 53600 records exist with the request parameters
#
# There was a problem with the following record:
# near "s": syntax error
# {'protocol': 'DWC_ARCHIVE', 'basisOfRecord': 'HUMAN_OBSERVATION', 'individualCount': 1, 'acceptedTaxonKey': 2489603, 'scientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'acceptedScientificName': 'Helmitheros vermivorum (J.F.Gmelin, 1789)', 'taxonomicStatus': 'ACCEPTED', 'decimalLongitude': -74.940971, 'decimalLatitude': 38.953483, 'year': 2018, 'month': 7, 'day': 28, 'eventDate': '2018-07-28T00:00:00', 'issues': [], 'geodeticDatum': 'WGS84', 'institutionCode': 'CLO', 'locality': 'Cape Island--CMBO\'s "The Roost" (restricted access)', 'gbifID': '2186056842', 'collectionCode': 'EBIRD', 'occurrenceID': 'URN:catalog:CLO:EBIRD:OBS643614284', 'remarks': '; Cape Island--CMBO\'s "The Roost" (restricted access)', 'dataGeneralizations': ''}
#
# Records saved in /Users/nmtarr/Documents/RANGES/Outputs/bwewax0GBIFr13GBIFf4.sqlite

# %% [markdown]
# ### How many records made it through the filters?
# This is the number that was actually saved in the occurrence record sqlite database.

# %%
conn_occ= sqlite3.connect(config.spdb)
curs_occ = conn_occ.cursor()
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE species_id = '{0}'".format(species_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 53564 records

# %% [markdown]
# ### Were there duplicate records?
# needs to be addressed

# %%
dups0 = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences GROUP BY geom_xy4326, occurrenceDate;").fetchall()
dups1 = [x[0] for x in dups0]
dups2 = [x for x in dups1 if x > 1]
print(str(len(dups2)) + ' records were duplicates based on xy coordinate and date-time')
# Out:
# 8377 records were duplicates based on xy coordinate and date-time

# %% [markdown]
# # Institutions
# #### Pre-filters

# %%
institutions = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'institutions';").fetchall()
for x in institutions:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# iNaturalist (88)
# CLO (53448)
# unknown (56)
# OMNH (1)
# http://biocol.org/urn:lsid:biocol.org:col:34795 (2)
# urn:lsid:biocol.org:col:34939 (2)
# naturgucker (2)
# UMMZ (1)

# %% [markdown]
# #### Post-filter

# %%
institutions = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'institutions' AND step = 'filter';").fetchone()[0]
institutions = institutions.replace('[', '').strip().replace(']', '').replace("'", "")
institutions = institutions.split(',')
for ins in institutions:
    print(ins.strip())
# Out:
# UNKNOWN
# naturgucker
# iNaturalist
# CLO

# %% [markdown]
# # Collections
# #### Pre-filters

# %%
collections = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'collections';").fetchall()
for x in collections:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# Observations (88)
# EBIRD (51514)
# EBIRD_VA (261)
# EBIRD_PA (691)
# EBIRD_WI (45)
# EBIRD_VINS (24)
# EBIRD_NJ (369)
# EBIRD_MO (18)
# EBIRD_CAMERICA (10)
# EBIRD_MA (53)
# Bird sounds (56)
# EBIRD_CAN (187)
# EBIRD_BCN (13)
# EBIRD_AK (4)
# EBIRD_TX (64)
# EBIRD_IND (2)
# EBIRD_QC (27)
# EBIRD_MEX (2)
# EBIRD_PNW (11)
# EBIRD_NH (8)
# OCGR (1)
# Birds (2)
# EBIRD_ME (1)
# EBIRD_CL (1)
# ML (2)
# EBIRD_PE (1)
# EBIRD_LWBA (141)
# naturgucker (2)
# EBIRD_PR (1)
# birds (1)

# %% [markdown]
# #### Post-filters

# %%
collections = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'collections' AND step = 'filter';").fetchone()[0]
collections = collections.replace('[', '').strip().replace(']', '').replace("'", "")
collections = collections.split(',')
for colls in collections:
    print(colls.strip())
# Out:
# EBIRD_MEX
# EBIRD_CL
# EBIRD_MO
# EBIRD
# EBIRD_PA
# EBIRD_BCN
# ML
# EBIRD_VA
# Bird sounds
# EBIRD_PE
# naturgucker
# EBIRD_TX
# EBIRD_LWBA
# EBIRD_QC
# EBIRD_PR
# EBIRD_CAN
# EBIRD_IND
# Observations
# EBIRD_MA
# EBIRD_PNW
# EBIRD_CAMERICA
# EBIRD_WI
# EBIRD_VINS
# EBIRD_NH
# EBIRD_AK
# EBIRD_ME
# EBIRD_NJ

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'bases';").fetchall()
for x in bases:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# HUMAN_OBSERVATION (53594)
# PRESERVED_SPECIMEN (4)
# MACHINE_OBSERVATION (2)

# %% [markdown]
# #### Post-filters

# %%
bases = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'bases' AND step = 'filter';").fetchone()[0]
bases = bases.replace('[', '').strip().replace(']', '').replace("'", "")
bases = bases.split(",")
for bas in bases:
    print(bas.strip())
# Out:
# MACHINE_OBSERVATION
# HUMAN_OBSERVATION

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocols = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'protocols';").fetchall()
for x in protocols:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# DWC_ARCHIVE (53598)
# BIOCASE (2)

# %% [markdown]
# #### Post-filters

# %%
protos = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'protocols' AND step = 'filter';").fetchall()[0]
for pro in protos:
    pro = pro.replace('[', '').strip().replace(']', '').replace("'", "")
    print(pro)
# Out:
# BIOCASE, DWC_ARCHIVE

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
issues = curs_occ.execute("SELECT value, count FROM post_request_value_counts WHERE attribute = 'issues';").fetchall()
for x in issues:
    print(x[0] + " ({0})".format(x[1]))
# Out:
# COORDINATE_ROUNDED (44479)
# GEODETIC_DATUM_ASSUMED_WGS84 (94)
# TAXON_MATCH_FUZZY (5)

# %% [markdown]
# #### Post-filters

# %%
issues = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'issues' AND step = 'filter';").fetchone()[0]
issues = issues.replace('[', '').strip().replace(']', '').replace("'", "")
issues = issues.split(',')
for iss in issues:
    print(iss.strip())
# Out:
# GEODETIC_DATUM_ASSUMED_WGS84
# COORDINATE_ROUNDED

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
gap_range2 = "{0}{1}_range_4326".format(inDir, gap_id)

shp1 = {'file': gap_range2, 'column': None, 'alias': 'GAP range map',
        'drawbounds': False, 'linewidth': .5, 'linecolor': 'y',
        'fillcolor': 'y', 'marker':'s'}

shp2 = {'file': '{0}{1}_circles'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'k',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
if os.path.isfile(gap_range2 + ".shp"):
    map_these=[shp1, shp2]
else:
    map_these=[shp2]
    
title="{1} ({0})".format(years, common_name)
functions.MapShapefilePolygons(map_these=map_these, title=title)

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(config.gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of occurrences")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of occurrences")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("coordinate uncertainty")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %% [markdown]
# ### Geodetic datums present

# %%
datums = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'datums' AND step = 'filter';").fetchone()[0]
datums = datums.replace('[', '').strip().replace(']', '').replace("'", "")
datums = datums.split()
for datum in datums:
    print(datum)
# Out:
# WGS84

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM record_attributes WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM record_attributes WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
#remarks = remarks.replace('[', '').strip().replace(']', '').replace("'", "")
#remarks = remarks.split(',')
if len(remarks) <= 20:
    for rem in remarks:
        if rem[0][0:1] == ';':
            print(rem[0][2:])
        else:
            print(rem[0])
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Sources

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [request_id, filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])
# Out:
# GBIF

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ, index_col='index')
fields_summary.index.name = 'field'
print(fields_summary)
# Out:
#                                       included(n)  populated(n)
# field
# acceptedScientificName                      53600         53600
# acceptedTaxonKey                            53600         53600
# accessRights                                    4             4
# associatedTaxa                                 35            35
# basisOfRecord                               53600         53600
# behavior                                       58            58
# catalogNumber                               53600         53600
# class                                       53600         53600
# classKey                                    53600         53600
# collectionCode                              53600         53600
# collectionID                                    2             2
# continent                                       6             6
# coordinateUncertaintyInMeters                  83            83
# country                                     53600         53600
# countryCode                                 53600         53600
# county                                      53434         53434
# crawlId                                     53600         53600
# dataGeneralizations                             2             2
# datasetID                                       2             2
# datasetKey                                  53600         53600
# datasetName                                    90            90
# dateIdentified                                 87            87
# day                                         53600         53600
# decimalLatitude                             53600         53600
# decimalLongitude                            53600         53600
# dynamicProperties                               1             1
# endDayOfYear                                    2             2
# establishmentMeans                              2             2
# eventDate                                   53600         53600
# eventTime                                     120           120
# extensions                                  53600             0
# facts                                       53600             0
# family                                      53600         53600
# familyKey                                   53600         53600
# fieldNotes                                     55            55
# gbifID                                      53600         53600
# genericName                                 53600         53600
# genus                                       53600         53600
# genusKey                                    53600         53600
# geodeticDatum                               53600         53600
# georeferenceProtocol                            3             3
# georeferenceSources                             1             1
# georeferenceVerificationStatus                  4             4
# georeferencedBy                                 1             1
# georeferencedDate                               1             1
# higherClassification                           59            59
# higherGeography                                 5             5
# http://unknown.org/occurrenceDetails           88            88
# http://unknown.org/recordedByOrcid              2             2
# identificationID                               87            87
# identifier                                  53598         53598
# identifiers                                 53600             0
# individualCount                             51105         51105
# informationWithheld                            26            26
# installationKey                             53600         53600
# institutionCode                             53544         53544
# institutionID                                   4             4
# issues                                      53600         44488
# key                                         53600         53600
# kingdom                                     53600         53600
# kingdomKey                                  53600         53600
# language                                        5             5
# lastCrawled                                 53600         53600
# lastInterpreted                             53600         53600
# lastParsed                                  53600         53600
# license                                     53600         53600
# locality                                    53512         53512
# locationRemarks                                 2             2
# media                                         131           131
# modified                                       91            91
# month                                       53600         53600
# networkKeys                                 53600             0
# nomenclaturalCode                              60            60
# occurrenceID                                53598         53598
# occurrenceRemarks                              22            22
# occurrenceStatus                                2             2
# order                                       53600         53600
# orderKey                                    53600         53600
# organismID                                      2             2
# otherCatalogNumbers                             1             1
# ownerInstitutionCode                            2             2
# phylum                                      53600         53600
# phylumKey                                   53600         53600
# preparations                                    3             3
# protocol                                    53600         53600
# publishingCountry                           53600         53600
# publishingOrgKey                            53600         53600
# recordNumber                                    3             3
# recordedBy                                  53598         53598
# references                                    146           146
# relations                                   53600             0
# rights                                         90            90
# rightsHolder                                  146           146
# scientificName                              53600         53600
# sex                                             3             3
# species                                     53600         53600
# speciesKey                                  53600         53600
# specificEpithet                             53600         53600
# startDayOfYear                                  4             4
# stateProvince                               53542         53542
# taxonID                                        88            88
# taxonKey                                    53600         53600
# taxonRank                                   53600         53600
# taxonomicStatus                             53600         53600
# type                                            4             4
# verbatimElevation                              58            58
# verbatimEventDate                             146           146
# verbatimLocality                               90            90
# vernacularName                                 59            59
# year                                        53600         53600

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 1:24:02.708789
